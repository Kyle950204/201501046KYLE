# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 161967 ## 기생충
total_count = 36754  ## 전체 크기=19,653

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201023150533" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201023150533" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201023150533" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201023150533" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="107924"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>19,674</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																마지막에 여자환호성 듣는영화 입니다 ㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8414887, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>pak9****</span>
# </a>
# </em>
# <em>2014.01.23 09:49</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','pak9****', 'vMKkx6u2U24KWtwKT7Hgx1TLN/c1PiixVm5t6RmIPwk=', '마지막에 여자환호성 듣는영화 입니다 ㅋㅋ ', '8414887', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8414887">2919</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8414887">167</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :)
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410149, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>enchanted(ench****)</span>
# </a>
# </em>
# <em>2014.01.22 13:08</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ench****', 'D/bKm65Iro/1mEGjvK5U9askMKD4OqNt+rQu8lM2GJk=', '스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :) ', '8410149', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410149">2929</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410149">534</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																마지막 장면을 잊을 수 없다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8411606, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>복부처(ming****)</span>
# </a>
# </em>
# <em>2014.01.22 18:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ming****', 'QJJ+sik4OFdzDhxau23rM0yT6I9mvi4PYtOSYdSSG1c=', '마지막 장면을 잊을 수 없다 ', '8411606', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8411606">1599</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8411606">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410187, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>thfx****</span>
# </a>
# </em>
# <em>2014.01.22 13:18</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','thfx****', 'LS05SctIqWA14ziNS069/gRP+bglldwGMMQ/9nFoyGs=', '심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!! ', '8410187', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410187">1205</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410187">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409809, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>미도리(luna****)</span>
# </a>
# </em>
# <em>2014.01.22 11:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','luna****', 'yqn6E3Splwd9g+qg9fPL6VtQCPJusrJy0Il14eeEQ/A=', '심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화! ', '8409809', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409809">994</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409809">75</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																평점8점대가뭐냐 9점이상짜리다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409952, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>wkdw****</span>
# </a>
# </em>
# <em>2014.01.22 12:14</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','wkdw****', 'xAu0nwVcpi48VAqTpTj/VNZI7oqzP3R0boV9WngnMus=', '평점8점대가뭐냐 9점이상짜리다 ', '8409952', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409952">1003</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409952">133</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																웃음과감동,두마리의토끼를다잡은가족영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409024, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>잘되는나(lh00****)</span>
# </a>
# </em>
# <em>2014.01.22 02:00</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lh00****', 'stueHIKT0+ti56DbQQNE7BgSmaIhY0lOCemnPP+2170=', '웃음과감동,두마리의토끼를다잡은가족영화 ', '8409024', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409024">821</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409024">113</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>아라리요(zzon****)</span>
# </a>
# </em>
# <em>2014.01.22 00:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','zzon****', 'W6Jl+l0NHKoFfFR+JvvBaHU4+mv8z4/QzQRqR0HHCvs=', '정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!! ', '8408627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408627">543</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408627">72</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "107924",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("107924", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('4670', '574')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'lmj7****'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2014, 1, 22, 0, 33)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 130966 ## 부산행
total_count = 58000  ## 전체 크기=58130

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....
# 1784 번째 페이지 parsing....
# 1785 번째 페이지 parsing....
# 1786 번째 페이지 parsing....
# 1787 번째 페이지 parsing....
# 1788 번째 페이지 parsing....
# 1789 번째 페이지 parsing....
# 1790 번째 페이지 parsing....
# 1791 번째 페이지 parsing....
# 1792 번째 페이지 parsing....
# 1793 번째 페이지 parsing....
# 1794 번째 페이지 parsing....
# 1795 번째 페이지 parsing....
# 1796 번째 페이지 parsing....
# 1797 번째 페이지 parsing....
# 1798 번째 페이지 parsing....
# 1799 번째 페이지 parsing....
# 1800 번째 페이지 parsing....
# 1801 번째 페이지 parsing....
# 1802 번째 페이지 parsing....
# 1803 번째 페이지 parsing....
# 1804 번째 페이지 parsing....
# 1805 번째 페이지 parsing....
# 1806 번째 페이지 parsing....
# 1807 번째 페이지 parsing....
# 1808 번째 페이지 parsing....
# 1809 번째 페이지 parsing....
# 1810 번째 페이지 parsing....
# 1811 번째 페이지 parsing....
# 1812 번째 페이지 parsing....
# 1813 번째 페이지 parsing....
# 1814 번째 페이지 parsing....
# 1815 번째 페이지 parsing....
# 1816 번째 페이지 parsing....
# 1817 번째 페이지 parsing....
# 1818 번째 페이지 parsing....
# 1819 번째 페이지 parsing....
# 1820 번째 페이지 parsing....
# 1821 번째 페이지 parsing....
# 1822 번째 페이지 parsing....
# 1823 번째 페이지 parsing....
# 1824 번째 페이지 parsing....
# 1825 번째 페이지 parsing....
# 1826 번째 페이지 parsing....
# 1827 번째 페이지 parsing....
# 1828 번째 페이지 parsing....
# 1829 번째 페이지 parsing....
# 1830 번째 페이지 parsing....
# 1831 번째 페이지 parsing....
# 1832 번째 페이지 parsing....
# 1833 번째 페이지 parsing....
# 1834 번째 페이지 parsing....
# 1835 번째 페이지 parsing....
# 1836 번째 페이지 parsing....
# 1837 번째 페이지 parsing....
# 1838 번째 페이지 parsing....
# 1839 번째 페이지 parsing....
# 1840 번째 페이지 parsing....
# 1841 번째 페이지 parsing....
# 1842 번째 페이지 parsing....
# 1843 번째 페이지 parsing....
# 1844 번째 페이지 parsing....
# 1845 번째 페이지 parsing....
# 1846 번째 페이지 parsing....
# 1847 번째 페이지 parsing....
# 1848 번째 페이지 parsing....
# 1849 번째 페이지 parsing....
# 1850 번째 페이지 parsing....
# 1851 번째 페이지 parsing....
# 1852 번째 페이지 parsing....
# 1853 번째 페이지 parsing....
# 1854 번째 페이지 parsing....
# 1855 번째 페이지 parsing....
# 1856 번째 페이지 parsing....
# 1857 번째 페이지 parsing....
# 1858 번째 페이지 parsing....
# 1859 번째 페이지 parsing....
# 1860 번째 페이지 parsing....
# 1861 번째 페이지 parsing....
# 1862 번째 페이지 parsing....
# 1863 번째 페이지 parsing....
# 1864 번째 페이지 parsing....
# 1865 번째 페이지 parsing....
# 1866 번째 페이지 parsing....
# 1867 번째 페이지 parsing....
# 1868 번째 페이지 parsing....
# 1869 번째 페이지 parsing....
# 1870 번째 페이지 parsing....
# 1871 번째 페이지 parsing....
# 1872 번째 페이지 parsing....
# 1873 번째 페이지 parsing....
# 1874 번째 페이지 parsing....
# 1875 번째 페이지 parsing....
# 1876 번째 페이지 parsing....
# 1877 번째 페이지 parsing....
# 1878 번째 페이지 parsing....
# 1879 번째 페이지 parsing....
# 1880 번째 페이지 parsing....
# 1881 번째 페이지 parsing....
# 1882 번째 페이지 parsing....
# 1883 번째 페이지 parsing....
# 1884 번째 페이지 parsing....
# 1885 번째 페이지 parsing....
# 1886 번째 페이지 parsing....
# 1887 번째 페이지 parsing....
# 1888 번째 페이지 parsing....
# 1889 번째 페이지 parsing....
# 1890 번째 페이지 parsing....
# 1891 번째 페이지 parsing....
# 1892 번째 페이지 parsing....
# 1893 번째 페이지 parsing....
# 1894 번째 페이지 parsing....
# 1895 번째 페이지 parsing....
# 1896 번째 페이지 parsing....
# 1897 번째 페이지 parsing....
# 1898 번째 페이지 parsing....
# 1899 번째 페이지 parsing....
# 1900 번째 페이지 parsing....
# 1901 번째 페이지 parsing....
# 1902 번째 페이지 parsing....
# 1903 번째 페이지 parsing....
# 1904 번째 페이지 parsing....
# 1905 번째 페이지 parsing....
# 1906 번째 페이지 parsing....
# 1907 번째 페이지 parsing....
# 1908 번째 페이지 parsing....
# 1909 번째 페이지 parsing....
# 1910 번째 페이지 parsing....
# 1911 번째 페이지 parsing....
# 1912 번째 페이지 parsing....
# 1913 번째 페이지 parsing....
# 1914 번째 페이지 parsing....
# 1915 번째 페이지 parsing....
# 1916 번째 페이지 parsing....
# 1917 번째 페이지 parsing....
# 1918 번째 페이지 parsing....
# 1919 번째 페이지 parsing....
# 1920 번째 페이지 parsing....
# 1921 번째 페이지 parsing....
# 1922 번째 페이지 parsing....
# 1923 번째 페이지 parsing....
# 1924 번째 페이지 parsing....
# 1925 번째 페이지 parsing....
# 1926 번째 페이지 parsing....
# 1927 번째 페이지 parsing....
# 1928 번째 페이지 parsing....
# 1929 번째 페이지 parsing....
# 1930 번째 페이지 parsing....
# 1931 번째 페이지 parsing....
# 1932 번째 페이지 parsing....
# 1933 번째 페이지 parsing....
# 1934 번째 페이지 parsing....
# 1935 번째 페이지 parsing....
# 1936 번째 페이지 parsing....
# 1937 번째 페이지 parsing....
# 1938 번째 페이지 parsing....
# 1939 번째 페이지 parsing....
# 1940 번째 페이지 parsing....
# 1941 번째 페이지 parsing....
# 1942 번째 페이지 parsing....
# 1943 번째 페이지 parsing....
# 1944 번째 페이지 parsing....
# 1945 번째 페이지 parsing....
# 1946 번째 페이지 parsing....
# 1947 번째 페이지 parsing....
# 1948 번째 페이지 parsing....
# 1949 번째 페이지 parsing....
# 1950 번째 페이지 parsing....
# 1951 번째 페이지 parsing....
# 1952 번째 페이지 parsing....
# 1953 번째 페이지 parsing....
# 1954 번째 페이지 parsing....
# 1955 번째 페이지 parsing....
# 1956 번째 페이지 parsing....
# 1957 번째 페이지 parsing....
# 1958 번째 페이지 parsing....
# 1959 번째 페이지 parsing....
# 1960 번째 페이지 parsing....
# 1961 번째 페이지 parsing....
# 1962 번째 페이지 parsing....
# 1963 번째 페이지 parsing....
# 1964 번째 페이지 parsing....
# 1965 번째 페이지 parsing....
# 1966 번째 페이지 parsing....
# 1967 번째 페이지 parsing....
# 1968 번째 페이지 parsing....
# 1969 번째 페이지 parsing....
# 1970 번째 페이지 parsing....
# 1971 번째 페이지 parsing....
# 1972 번째 페이지 parsing....
# 1973 번째 페이지 parsing....
# 1974 번째 페이지 parsing....
# 1975 번째 페이지 parsing....
# 1976 번째 페이지 parsing....
# 1977 번째 페이지 parsing....
# 1978 번째 페이지 parsing....
# 1979 번째 페이지 parsing....
# 1980 번째 페이지 parsing....
# 1981 번째 페이지 parsing....
# 1982 번째 페이지 parsing....
# 1983 번째 페이지 parsing....
# 1984 번째 페이지 parsing....
# 1985 번째 페이지 parsing....
# 1986 번째 페이지 parsing....
# 1987 번째 페이지 parsing....
# 1988 번째 페이지 parsing....
# 1989 번째 페이지 parsing....
# 1990 번째 페이지 parsing....
# 1991 번째 페이지 parsing....
# 1992 번째 페이지 parsing....
# 1993 번째 페이지 parsing....
# 1994 번째 페이지 parsing....
# 1995 번째 페이지 parsing....
# 1996 번째 페이지 parsing....
# 1997 번째 페이지 parsing....
# 1998 번째 페이지 parsing....
# 1999 번째 페이지 parsing....
# 2000 번째 페이지 parsing....
# 2001 번째 페이지 parsing....
# 2002 번째 페이지 parsing....
# 2003 번째 페이지 parsing....
# 2004 번째 페이지 parsing....
# 2005 번째 페이지 parsing....
# 2006 번째 페이지 parsing....
# 2007 번째 페이지 parsing....
# 2008 번째 페이지 parsing....
# 2009 번째 페이지 parsing....
# 2010 번째 페이지 parsing....
# 2011 번째 페이지 parsing....
# 2012 번째 페이지 parsing....
# 2013 번째 페이지 parsing....
# 2014 번째 페이지 parsing....
# 2015 번째 페이지 parsing....
# 2016 번째 페이지 parsing....
# 2017 번째 페이지 parsing....
# 2018 번째 페이지 parsing....
# 2019 번째 페이지 parsing....
# 2020 번째 페이지 parsing....
# 2021 번째 페이지 parsing....
# 2022 번째 페이지 parsing....
# 2023 번째 페이지 parsing....
# 2024 번째 페이지 parsing....
# 2025 번째 페이지 parsing....
# 2026 번째 페이지 parsing....
# 2027 번째 페이지 parsing....
# 2028 번째 페이지 parsing....
# 2029 번째 페이지 parsing....
# 2030 번째 페이지 parsing....
# 2031 번째 페이지 parsing....
# 2032 번째 페이지 parsing....
# 2033 번째 페이지 parsing....
# 2034 번째 페이지 parsing....
# 2035 번째 페이지 parsing....
# 2036 번째 페이지 parsing....
# 2037 번째 페이지 parsing....
# 2038 번째 페이지 parsing....
# 2039 번째 페이지 parsing....
# 2040 번째 페이지 parsing....
# 2041 번째 페이지 parsing....
# 2042 번째 페이지 parsing....
# 2043 번째 페이지 parsing....
# 2044 번째 페이지 parsing....
# 2045 번째 페이지 parsing....
# 2046 번째 페이지 parsing....
# 2047 번째 페이지 parsing....
# 2048 번째 페이지 parsing....
# 2049 번째 페이지 parsing....
# 2050 번째 페이지 parsing....
# 2051 번째 페이지 parsing....
# 2052 번째 페이지 parsing....
# 2053 번째 페이지 parsing....
# 2054 번째 페이지 parsing....
# 2055 번째 페이지 parsing....
# 2056 번째 페이지 parsing....
# 2057 번째 페이지 parsing....
# 2058 번째 페이지 parsing....
# 2059 번째 페이지 parsing....
# 2060 번째 페이지 parsing....
# 2061 번째 페이지 parsing....
# 2062 번째 페이지 parsing....
# 2063 번째 페이지 parsing....
# 2064 번째 페이지 parsing....
# 2065 번째 페이지 parsing....
# 2066 번째 페이지 parsing....
# 2067 번째 페이지 parsing....
# 2068 번째 페이지 parsing....
# 2069 번째 페이지 parsing....
# 2070 번째 페이지 parsing....
# 2071 번째 페이지 parsing....
# 2072 번째 페이지 parsing....
# 2073 번째 페이지 parsing....
# 2074 번째 페이지 parsing....
# 2075 번째 페이지 parsing....
# 2076 번째 페이지 parsing....
# 2077 번째 페이지 parsing....
# 2078 번째 페이지 parsing....
# 2079 번째 페이지 parsing....
# 2080 번째 페이지 parsing....
# 2081 번째 페이지 parsing....
# 2082 번째 페이지 parsing....
# 2083 번째 페이지 parsing....
# 2084 번째 페이지 parsing....
# 2085 번째 페이지 parsing....
# 2086 번째 페이지 parsing....
# 2087 번째 페이지 parsing....
# 2088 번째 페이지 parsing....
# 2089 번째 페이지 parsing....
# 2090 번째 페이지 parsing....
# 2091 번째 페이지 parsing....
# 2092 번째 페이지 parsing....
# 2093 번째 페이지 parsing....
# 2094 번째 페이지 parsing....
# 2095 번째 페이지 parsing....
# 2096 번째 페이지 parsing....
# 2097 번째 페이지 parsing....
# 2098 번째 페이지 parsing....
# 2099 번째 페이지 parsing....
# 2100 번째 페이지 parsing....
# 2101 번째 페이지 parsing....
# 2102 번째 페이지 parsing....
# 2103 번째 페이지 parsing....
# 2104 번째 페이지 parsing....
# 2105 번째 페이지 parsing....
# 2106 번째 페이지 parsing....
# 2107 번째 페이지 parsing....
# 2108 번째 페이지 parsing....
# 2109 번째 페이지 parsing....
# 2110 번째 페이지 parsing....
# 2111 번째 페이지 parsing....
# 2112 번째 페이지 parsing....
# 2113 번째 페이지 parsing....
# 2114 번째 페이지 parsing....
# 2115 번째 페이지 parsing....
# 2116 번째 페이지 parsing....
# 2117 번째 페이지 parsing....
# 2118 번째 페이지 parsing....
# 2119 번째 페이지 parsing....
# 2120 번째 페이지 parsing....
# 2121 번째 페이지 parsing....
# 2122 번째 페이지 parsing....
# 2123 번째 페이지 parsing....
# 2124 번째 페이지 parsing....
# 2125 번째 페이지 parsing....
# 2126 번째 페이지 parsing....
# 2127 번째 페이지 parsing....
# 2128 번째 페이지 parsing....
# 2129 번째 페이지 parsing....
# 2130 번째 페이지 parsing....
# 2131 번째 페이지 parsing....
# 2132 번째 페이지 parsing....
# 2133 번째 페이지 parsing....
# 2134 번째 페이지 parsing....
# 2135 번째 페이지 parsing....
# 2136 번째 페이지 parsing....
# 2137 번째 페이지 parsing....
# 2138 번째 페이지 parsing....
# 2139 번째 페이지 parsing....
# 2140 번째 페이지 parsing....
# 2141 번째 페이지 parsing....
# 2142 번째 페이지 parsing....
# 2143 번째 페이지 parsing....
# 2144 번째 페이지 parsing....
# 2145 번째 페이지 parsing....
# 2146 번째 페이지 parsing....
# 2147 번째 페이지 parsing....
# 2148 번째 페이지 parsing....
# 2149 번째 페이지 parsing....
# 2150 번째 페이지 parsing....
# 2151 번째 페이지 parsing....
# 2152 번째 페이지 parsing....
# 2153 번째 페이지 parsing....
# 2154 번째 페이지 parsing....
# 2155 번째 페이지 parsing....
# 2156 번째 페이지 parsing....
# 2157 번째 페이지 parsing....
# 2158 번째 페이지 parsing....
# 2159 번째 페이지 parsing....
# 2160 번째 페이지 parsing....
# 2161 번째 페이지 parsing....
# 2162 번째 페이지 parsing....
# 2163 번째 페이지 parsing....
# 2164 번째 페이지 parsing....
# 2165 번째 페이지 parsing....
# 2166 번째 페이지 parsing....
# 2167 번째 페이지 parsing....
# 2168 번째 페이지 parsing....
# 2169 번째 페이지 parsing....
# 2170 번째 페이지 parsing....
# 2171 번째 페이지 parsing....
# 2172 번째 페이지 parsing....
# 2173 번째 페이지 parsing....
# 2174 번째 페이지 parsing....
# 2175 번째 페이지 parsing....
# 2176 번째 페이지 parsing....
# 2177 번째 페이지 parsing....
# 2178 번째 페이지 parsing....
# 2179 번째 페이지 parsing....
# 2180 번째 페이지 parsing....
# 2181 번째 페이지 parsing....
# 2182 번째 페이지 parsing....
# 2183 번째 페이지 parsing....
# 2184 번째 페이지 parsing....
# 2185 번째 페이지 parsing....
# 2186 번째 페이지 parsing....
# 2187 번째 페이지 parsing....
# 2188 번째 페이지 parsing....
# 2189 번째 페이지 parsing....
# 2190 번째 페이지 parsing....
# 2191 번째 페이지 parsing....
# 2192 번째 페이지 parsing....
# 2193 번째 페이지 parsing....
# 2194 번째 페이지 parsing....
# 2195 번째 페이지 parsing....
# 2196 번째 페이지 parsing....
# 2197 번째 페이지 parsing....
# 2198 번째 페이지 parsing....
# 2199 번째 페이지 parsing....
# 2200 번째 페이지 parsing....
# 2201 번째 페이지 parsing....
# 2202 번째 페이지 parsing....
# 2203 번째 페이지 parsing....
# 2204 번째 페이지 parsing....
# 2205 번째 페이지 parsing....
# 2206 번째 페이지 parsing....
# 2207 번째 페이지 parsing....
# 2208 번째 페이지 parsing....
# 2209 번째 페이지 parsing....
# 2210 번째 페이지 parsing....
# 2211 번째 페이지 parsing....
# 2212 번째 페이지 parsing....
# 2213 번째 페이지 parsing....
# 2214 번째 페이지 parsing....
# 2215 번째 페이지 parsing....
# 2216 번째 페이지 parsing....
# 2217 번째 페이지 parsing....
# 2218 번째 페이지 parsing....
# 2219 번째 페이지 parsing....
# 2220 번째 페이지 parsing....
# 2221 번째 페이지 parsing....
# 2222 번째 페이지 parsing....
# 2223 번째 페이지 parsing....
# 2224 번째 페이지 parsing....
# 2225 번째 페이지 parsing....
# 2226 번째 페이지 parsing....
# 2227 번째 페이지 parsing....
# 2228 번째 페이지 parsing....
# 2229 번째 페이지 parsing....
# 2230 번째 페이지 parsing....
# 2231 번째 페이지 parsing....
# 2232 번째 페이지 parsing....
# 2233 번째 페이지 parsing....
# 2234 번째 페이지 parsing....
# 2235 번째 페이지 parsing....
# 2236 번째 페이지 parsing....
# 2237 번째 페이지 parsing....
# 2238 번째 페이지 parsing....
# 2239 번째 페이지 parsing....
# 2240 번째 페이지 parsing....
# 2241 번째 페이지 parsing....
# 2242 번째 페이지 parsing....
# 2243 번째 페이지 parsing....
# 2244 번째 페이지 parsing....
# 2245 번째 페이지 parsing....
# 2246 번째 페이지 parsing....
# 2247 번째 페이지 parsing....
# 2248 번째 페이지 parsing....
# 2249 번째 페이지 parsing....
# 2250 번째 페이지 parsing....
# 2251 번째 페이지 parsing....
# 2252 번째 페이지 parsing....
# 2253 번째 페이지 parsing....
# 2254 번째 페이지 parsing....
# 2255 번째 페이지 parsing....
# 2256 번째 페이지 parsing....
# 2257 번째 페이지 parsing....
# 2258 번째 페이지 parsing....
# 2259 번째 페이지 parsing....
# 2260 번째 페이지 parsing....
# 2261 번째 페이지 parsing....
# 2262 번째 페이지 parsing....
# 2263 번째 페이지 parsing....
# 2264 번째 페이지 parsing....
# 2265 번째 페이지 parsing....
# 2266 번째 페이지 parsing....
# 2267 번째 페이지 parsing....
# 2268 번째 페이지 parsing....
# 2269 번째 페이지 parsing....
# 2270 번째 페이지 parsing....
# 2271 번째 페이지 parsing....
# 2272 번째 페이지 parsing....
# 2273 번째 페이지 parsing....
# 2274 번째 페이지 parsing....
# 2275 번째 페이지 parsing....
# 2276 번째 페이지 parsing....
# 2277 번째 페이지 parsing....
# 2278 번째 페이지 parsing....
# 2279 번째 페이지 parsing....
# 2280 번째 페이지 parsing....
# 2281 번째 페이지 parsing....
# 2282 번째 페이지 parsing....
# 2283 번째 페이지 parsing....
# 2284 번째 페이지 parsing....
# 2285 번째 페이지 parsing....
# 2286 번째 페이지 parsing....
# 2287 번째 페이지 parsing....
# 2288 번째 페이지 parsing....
# 2289 번째 페이지 parsing....
# 2290 번째 페이지 parsing....
# 2291 번째 페이지 parsing....
# 2292 번째 페이지 parsing....
# 2293 번째 페이지 parsing....
# 2294 번째 페이지 parsing....
# 2295 번째 페이지 parsing....
# 2296 번째 페이지 parsing....
# 2297 번째 페이지 parsing....
# 2298 번째 페이지 parsing....
# 2299 번째 페이지 parsing....
# 2300 번째 페이지 parsing....
# 2301 번째 페이지 parsing....
# 2302 번째 페이지 parsing....
# 2303 번째 페이지 parsing....
# 2304 번째 페이지 parsing....
# 2305 번째 페이지 parsing....
# 2306 번째 페이지 parsing....
# 2307 번째 페이지 parsing....
# 2308 번째 페이지 parsing....
# 2309 번째 페이지 parsing....
# 2310 번째 페이지 parsing....
# 2311 번째 페이지 parsing....
# 2312 번째 페이지 parsing....
# 2313 번째 페이지 parsing....
# 2314 번째 페이지 parsing....
# 2315 번째 페이지 parsing....
# 2316 번째 페이지 parsing....
# 2317 번째 페이지 parsing....
# 2318 번째 페이지 parsing....
# 2319 번째 페이지 parsing....
# 2320 번째 페이지 parsing....
# 2321 번째 페이지 parsing....
# 2322 번째 페이지 parsing....
# 2323 번째 페이지 parsing....
# 2324 번째 페이지 parsing....
# 2325 번째 페이지 parsing....
# 2326 번째 페이지 parsing....
# 2327 번째 페이지 parsing....
# 2328 번째 페이지 parsing....
# 2329 번째 페이지 parsing....
# 2330 번째 페이지 parsing....
# 2331 번째 페이지 parsing....
# 2332 번째 페이지 parsing....
# 2333 번째 페이지 parsing....
# 2334 번째 페이지 parsing....
# 2335 번째 페이지 parsing....
# 2336 번째 페이지 parsing....
# 2337 번째 페이지 parsing....
# 2338 번째 페이지 parsing....
# 2339 번째 페이지 parsing....
# 2340 번째 페이지 parsing....
# 2341 번째 페이지 parsing....
# 2342 번째 페이지 parsing....
# 2343 번째 페이지 parsing....
# 2344 번째 페이지 parsing....
# 2345 번째 페이지 parsing....
# 2346 번째 페이지 parsing....
# 2347 번째 페이지 parsing....
# 2348 번째 페이지 parsing....
# 2349 번째 페이지 parsing....
# 2350 번째 페이지 parsing....
# 2351 번째 페이지 parsing....
# 2352 번째 페이지 parsing....
# 2353 번째 페이지 parsing....
# 2354 번째 페이지 parsing....
# 2355 번째 페이지 parsing....
# 2356 번째 페이지 parsing....
# 2357 번째 페이지 parsing....
# 2358 번째 페이지 parsing....
# 2359 번째 페이지 parsing....
# 2360 번째 페이지 parsing....
# 2361 번째 페이지 parsing....
# 2362 번째 페이지 parsing....
# 2363 번째 페이지 parsing....
# 2364 번째 페이지 parsing....
# 2365 번째 페이지 parsing....
# 2366 번째 페이지 parsing....
# 2367 번째 페이지 parsing....
# 2368 번째 페이지 parsing....
# 2369 번째 페이지 parsing....
# 2370 번째 페이지 parsing....
# 2371 번째 페이지 parsing....
# 2372 번째 페이지 parsing....
# 2373 번째 페이지 parsing....
# 2374 번째 페이지 parsing....
# 2375 번째 페이지 parsing....
# 2376 번째 페이지 parsing....
# 2377 번째 페이지 parsing....
# 2378 번째 페이지 parsing....
# 2379 번째 페이지 parsing....
# 2380 번째 페이지 parsing....
# 2381 번째 페이지 parsing....
# 2382 번째 페이지 parsing....
# 2383 번째 페이지 parsing....
# 2384 번째 페이지 parsing....
# 2385 번째 페이지 parsing....
# 2386 번째 페이지 parsing....
# 2387 번째 페이지 parsing....
# 2388 번째 페이지 parsing....
# 2389 번째 페이지 parsing....
# 2390 번째 페이지 parsing....
# 2391 번째 페이지 parsing....
# 2392 번째 페이지 parsing....
# 2393 번째 페이지 parsing....
# 2394 번째 페이지 parsing....
# 2395 번째 페이지 parsing....
# 2396 번째 페이지 parsing....
# 2397 번째 페이지 parsing....
# 2398 번째 페이지 parsing....
# 2399 번째 페이지 parsing....
# 2400 번째 페이지 parsing....
# 2401 번째 페이지 parsing....
# 2402 번째 페이지 parsing....
# 2403 번째 페이지 parsing....
# 2404 번째 페이지 parsing....
# 2405 번째 페이지 parsing....
# 2406 번째 페이지 parsing....
# 2407 번째 페이지 parsing....
# 2408 번째 페이지 parsing....
# 2409 번째 페이지 parsing....
# 2410 번째 페이지 parsing....
# 2411 번째 페이지 parsing....
# 2412 번째 페이지 parsing....
# 2413 번째 페이지 parsing....
# 2414 번째 페이지 parsing....
# 2415 번째 페이지 parsing....
# 2416 번째 페이지 parsing....
# 2417 번째 페이지 parsing....
# 2418 번째 페이지 parsing....
# 2419 번째 페이지 parsing....
# 2420 번째 페이지 parsing....
# 2421 번째 페이지 parsing....
# 2422 번째 페이지 parsing....
# 2423 번째 페이지 parsing....
# 2424 번째 페이지 parsing....
# 2425 번째 페이지 parsing....
# 2426 번째 페이지 parsing....
# 2427 번째 페이지 parsing....
# 2428 번째 페이지 parsing....
# 2429 번째 페이지 parsing....
# 2430 번째 페이지 parsing....
# 2431 번째 페이지 parsing....
# 2432 번째 페이지 parsing....
# 2433 번째 페이지 parsing....
# 2434 번째 페이지 parsing....
# 2435 번째 페이지 parsing....
# 2436 번째 페이지 parsing....
# 2437 번째 페이지 parsing....
# 2438 번째 페이지 parsing....
# 2439 번째 페이지 parsing....
# 2440 번째 페이지 parsing....
# 2441 번째 페이지 parsing....
# 2442 번째 페이지 parsing....
# 2443 번째 페이지 parsing....
# 2444 번째 페이지 parsing....
# 2445 번째 페이지 parsing....
# 2446 번째 페이지 parsing....
# 2447 번째 페이지 parsing....
# 2448 번째 페이지 parsing....
# 2449 번째 페이지 parsing....
# 2450 번째 페이지 parsing....
# 2451 번째 페이지 parsing....
# 2452 번째 페이지 parsing....
# 2453 번째 페이지 parsing....
# 2454 번째 페이지 parsing....
# 2455 번째 페이지 parsing....
# 2456 번째 페이지 parsing....
# 2457 번째 페이지 parsing....
# 2458 번째 페이지 parsing....
# 2459 번째 페이지 parsing....
# 2460 번째 페이지 parsing....
# 2461 번째 페이지 parsing....
# 2462 번째 페이지 parsing....
# 2463 번째 페이지 parsing....
# 2464 번째 페이지 parsing....
# 2465 번째 페이지 parsing....
# 2466 번째 페이지 parsing....
# 2467 번째 페이지 parsing....
# 2468 번째 페이지 parsing....
# 2469 번째 페이지 parsing....
# 2470 번째 페이지 parsing....
# 2471 번째 페이지 parsing....
# 2472 번째 페이지 parsing....
# 2473 번째 페이지 parsing....
# 2474 번째 페이지 parsing....
# 2475 번째 페이지 parsing....
# 2476 번째 페이지 parsing....
# 2477 번째 페이지 parsing....
# 2478 번째 페이지 parsing....
# 2479 번째 페이지 parsing....
# 2480 번째 페이지 parsing....
# 2481 번째 페이지 parsing....
# 2482 번째 페이지 parsing....
# 2483 번째 페이지 parsing....
# 2484 번째 페이지 parsing....
# 2485 번째 페이지 parsing....
# 2486 번째 페이지 parsing....
# 2487 번째 페이지 parsing....
# 2488 번째 페이지 parsing....
# 2489 번째 페이지 parsing....
# 2490 번째 페이지 parsing....
# 2491 번째 페이지 parsing....
# 2492 번째 페이지 parsing....
# 2493 번째 페이지 parsing....
# 2494 번째 페이지 parsing....
# 2495 번째 페이지 parsing....
# 2496 번째 페이지 parsing....
# 2497 번째 페이지 parsing....
# 2498 번째 페이지 parsing....
# 2499 번째 페이지 parsing....
# 2500 번째 페이지 parsing....
# 2501 번째 페이지 parsing....
# 2502 번째 페이지 parsing....
# 2503 번째 페이지 parsing....
# 2504 번째 페이지 parsing....
# 2505 번째 페이지 parsing....
# 2506 번째 페이지 parsing....
# 2507 번째 페이지 parsing....
# 2508 번째 페이지 parsing....
# 2509 번째 페이지 parsing....
# 2510 번째 페이지 parsing....
# 2511 번째 페이지 parsing....
# 2512 번째 페이지 parsing....
# 2513 번째 페이지 parsing....
# 2514 번째 페이지 parsing....
# 2515 번째 페이지 parsing....
# 2516 번째 페이지 parsing....
# 2517 번째 페이지 parsing....
# 2518 번째 페이지 parsing....
# 2519 번째 페이지 parsing....
# 2520 번째 페이지 parsing....
# 2521 번째 페이지 parsing....
# 2522 번째 페이지 parsing....
# 2523 번째 페이지 parsing....
# 2524 번째 페이지 parsing....
# 2525 번째 페이지 parsing....
# 2526 번째 페이지 parsing....
# 2527 번째 페이지 parsing....
# 2528 번째 페이지 parsing....
# 2529 번째 페이지 parsing....
# 2530 번째 페이지 parsing....
# 2531 번째 페이지 parsing....
# 2532 번째 페이지 parsing....
# 2533 번째 페이지 parsing....
# 2534 번째 페이지 parsing....
# 2535 번째 페이지 parsing....
# 2536 번째 페이지 parsing....
# 2537 번째 페이지 parsing....
# 2538 번째 페이지 parsing....
# 2539 번째 페이지 parsing....
# 2540 번째 페이지 parsing....
# 2541 번째 페이지 parsing....
# 2542 번째 페이지 parsing....
# 2543 번째 페이지 parsing....
# 2544 번째 페이지 parsing....
# 2545 번째 페이지 parsing....
# 2546 번째 페이지 parsing....
# 2547 번째 페이지 parsing....
# 2548 번째 페이지 parsing....
# 2549 번째 페이지 parsing....
# 2550 번째 페이지 parsing....
# 2551 번째 페이지 parsing....
# 2552 번째 페이지 parsing....
# 2553 번째 페이지 parsing....
# 2554 번째 페이지 parsing....
# 2555 번째 페이지 parsing....
# 2556 번째 페이지 parsing....
# 2557 번째 페이지 parsing....
# 2558 번째 페이지 parsing....
# 2559 번째 페이지 parsing....
# 2560 번째 페이지 parsing....
# 2561 번째 페이지 parsing....
# 2562 번째 페이지 parsing....
# 2563 번째 페이지 parsing....
# 2564 번째 페이지 parsing....
# 2565 번째 페이지 parsing....
# 2566 번째 페이지 parsing....
# 2567 번째 페이지 parsing....
# 2568 번째 페이지 parsing....
# 2569 번째 페이지 parsing....
# 2570 번째 페이지 parsing....
# 2571 번째 페이지 parsing....
# 2572 번째 페이지 parsing....
# 2573 번째 페이지 parsing....
# 2574 번째 페이지 parsing....
# 2575 번째 페이지 parsing....
# 2576 번째 페이지 parsing....
# 2577 번째 페이지 parsing....
# 2578 번째 페이지 parsing....
# 2579 번째 페이지 parsing....
# 2580 번째 페이지 parsing....
# 2581 번째 페이지 parsing....
# 2582 번째 페이지 parsing....
# 2583 번째 페이지 parsing....
# 2584 번째 페이지 parsing....
# 2585 번째 페이지 parsing....
# 2586 번째 페이지 parsing....
# 2587 번째 페이지 parsing....
# 2588 번째 페이지 parsing....
# 2589 번째 페이지 parsing....
# 2590 번째 페이지 parsing....
# 2591 번째 페이지 parsing....
# 2592 번째 페이지 parsing....
# 2593 번째 페이지 parsing....
# 2594 번째 페이지 parsing....
# 2595 번째 페이지 parsing....
# 2596 번째 페이지 parsing....
# 2597 번째 페이지 parsing....
# 2598 번째 페이지 parsing....
# 2599 번째 페이지 parsing....
# 2600 번째 페이지 parsing....
# 2601 번째 페이지 parsing....
# 2602 번째 페이지 parsing....
# 2603 번째 페이지 parsing....
# 2604 번째 페이지 parsing....
# 2605 번째 페이지 parsing....
# 2606 번째 페이지 parsing....
# 2607 번째 페이지 parsing....
# 2608 번째 페이지 parsing....
# 2609 번째 페이지 parsing....
# 2610 번째 페이지 parsing....
# 2611 번째 페이지 parsing....
# 2612 번째 페이지 parsing....
# 2613 번째 페이지 parsing....
# 2614 번째 페이지 parsing....
# 2615 번째 페이지 parsing....
# 2616 번째 페이지 parsing....
# 2617 번째 페이지 parsing....
# 2618 번째 페이지 parsing....
# 2619 번째 페이지 parsing....
# 2620 번째 페이지 parsing....
# 2621 번째 페이지 parsing....
# 2622 번째 페이지 parsing....
# 2623 번째 페이지 parsing....
# 2624 번째 페이지 parsing....
# 2625 번째 페이지 parsing....
# 2626 번째 페이지 parsing....
# 2627 번째 페이지 parsing....
# 2628 번째 페이지 parsing....
# 2629 번째 페이지 parsing....
# 2630 번째 페이지 parsing....
# 2631 번째 페이지 parsing....
# 2632 번째 페이지 parsing....
# 2633 번째 페이지 parsing....
# 2634 번째 페이지 parsing....
# 2635 번째 페이지 parsing....
# 2636 번째 페이지 parsing....
# 2637 번째 페이지 parsing....
# 2638 번째 페이지 parsing....
# 2639 번째 페이지 parsing....
# 2640 번째 페이지 parsing....
# 2641 번째 페이지 parsing....
# 2642 번째 페이지 parsing....
# 2643 번째 페이지 parsing....
# 2644 번째 페이지 parsing....
# 2645 번째 페이지 parsing....
# 2646 번째 페이지 parsing....
# 2647 번째 페이지 parsing....
# 2648 번째 페이지 parsing....
# 2649 번째 페이지 parsing....
# 2650 번째 페이지 parsing....
# 2651 번째 페이지 parsing....
# 2652 번째 페이지 parsing....
# 2653 번째 페이지 parsing....
# 2654 번째 페이지 parsing....
# 2655 번째 페이지 parsing....
# 2656 번째 페이지 parsing....
# 2657 번째 페이지 parsing....
# 2658 번째 페이지 parsing....
# 2659 번째 페이지 parsing....
# 2660 번째 페이지 parsing....
# 2661 번째 페이지 parsing....
# 2662 번째 페이지 parsing....
# 2663 번째 페이지 parsing....
# 2664 번째 페이지 parsing....
# 2665 번째 페이지 parsing....
# 2666 번째 페이지 parsing....
# 2667 번째 페이지 parsing....
# 2668 번째 페이지 parsing....
# 2669 번째 페이지 parsing....
# 2670 번째 페이지 parsing....
# 2671 번째 페이지 parsing....
# 2672 번째 페이지 parsing....
# 2673 번째 페이지 parsing....
# 2674 번째 페이지 parsing....
# 2675 번째 페이지 parsing....
# 2676 번째 페이지 parsing....
# 2677 번째 페이지 parsing....
# 2678 번째 페이지 parsing....
# 2679 번째 페이지 parsing....
# 2680 번째 페이지 parsing....
# 2681 번째 페이지 parsing....
# 2682 번째 페이지 parsing....
# 2683 번째 페이지 parsing....
# 2684 번째 페이지 parsing....
# 2685 번째 페이지 parsing....
# 2686 번째 페이지 parsing....
# 2687 번째 페이지 parsing....
# 2688 번째 페이지 parsing....
# 2689 번째 페이지 parsing....
# 2690 번째 페이지 parsing....
# 2691 번째 페이지 parsing....
# 2692 번째 페이지 parsing....
# 2693 번째 페이지 parsing....
# 2694 번째 페이지 parsing....
# 2695 번째 페이지 parsing....
# 2696 번째 페이지 parsing....
# 2697 번째 페이지 parsing....
# 2698 번째 페이지 parsing....
# 2699 번째 페이지 parsing....
# 2700 번째 페이지 parsing....
# 2701 번째 페이지 parsing....
# 2702 번째 페이지 parsing....
# 2703 번째 페이지 parsing....
# 2704 번째 페이지 parsing....
# 2705 번째 페이지 parsing....
# 2706 번째 페이지 parsing....
# 2707 번째 페이지 parsing....
# 2708 번째 페이지 parsing....
# 2709 번째 페이지 parsing....
# 2710 번째 페이지 parsing....
# 2711 번째 페이지 parsing....
# 2712 번째 페이지 parsing....
# 2713 번째 페이지 parsing....
# 2714 번째 페이지 parsing....
# 2715 번째 페이지 parsing....
# 2716 번째 페이지 parsing....
# 2717 번째 페이지 parsing....
# 2718 번째 페이지 parsing....
# 2719 번째 페이지 parsing....
# 2720 번째 페이지 parsing....
# 2721 번째 페이지 parsing....
# 2722 번째 페이지 parsing....
# 2723 번째 페이지 parsing....
# 2724 번째 페이지 parsing....
# 2725 번째 페이지 parsing....
# 2726 번째 페이지 parsing....
# 2727 번째 페이지 parsing....
# 2728 번째 페이지 parsing....
# 2729 번째 페이지 parsing....
# 2730 번째 페이지 parsing....
# 2731 번째 페이지 parsing....
# 2732 번째 페이지 parsing....
# 2733 번째 페이지 parsing....
# 2734 번째 페이지 parsing....
# 2735 번째 페이지 parsing....
# 2736 번째 페이지 parsing....
# 2737 번째 페이지 parsing....
# 2738 번째 페이지 parsing....
# 2739 번째 페이지 parsing....
# 2740 번째 페이지 parsing....
# 2741 번째 페이지 parsing....
# 2742 번째 페이지 parsing....
# 2743 번째 페이지 parsing....
# 2744 번째 페이지 parsing....
# 2745 번째 페이지 parsing....
# 2746 번째 페이지 parsing....
# 2747 번째 페이지 parsing....
# 2748 번째 페이지 parsing....
# 2749 번째 페이지 parsing....
# 2750 번째 페이지 parsing....
# 2751 번째 페이지 parsing....
# 2752 번째 페이지 parsing....
# 2753 번째 페이지 parsing....
# 2754 번째 페이지 parsing....
# 2755 번째 페이지 parsing....
# 2756 번째 페이지 parsing....
# 2757 번째 페이지 parsing....
# 2758 번째 페이지 parsing....
# 2759 번째 페이지 parsing....
# 2760 번째 페이지 parsing....
# 2761 번째 페이지 parsing....
# 2762 번째 페이지 parsing....
# 2763 번째 페이지 parsing....
# 2764 번째 페이지 parsing....
# 2765 번째 페이지 parsing....
# 2766 번째 페이지 parsing....
# 2767 번째 페이지 parsing....
# 2768 번째 페이지 parsing....
# 2769 번째 페이지 parsing....
# 2770 번째 페이지 parsing....
# 2771 번째 페이지 parsing....
# 2772 번째 페이지 parsing....
# 2773 번째 페이지 parsing....
# 2774 번째 페이지 parsing....
# 2775 번째 페이지 parsing....
# 2776 번째 페이지 parsing....
# 2777 번째 페이지 parsing....
# 2778 번째 페이지 parsing....
# 2779 번째 페이지 parsing....
# 2780 번째 페이지 parsing....
# 2781 번째 페이지 parsing....
# 2782 번째 페이지 parsing....
# 2783 번째 페이지 parsing....
# 2784 번째 페이지 parsing....
# 2785 번째 페이지 parsing....
# 2786 번째 페이지 parsing....
# 2787 번째 페이지 parsing....
# 2788 번째 페이지 parsing....
# 2789 번째 페이지 parsing....
# 2790 번째 페이지 parsing....
# 2791 번째 페이지 parsing....
# 2792 번째 페이지 parsing....
# 2793 번째 페이지 parsing....
# 2794 번째 페이지 parsing....
# 2795 번째 페이지 parsing....
# 2796 번째 페이지 parsing....
# 2797 번째 페이지 parsing....
# 2798 번째 페이지 parsing....
# 2799 번째 페이지 parsing....
# 2800 번째 페이지 parsing....
# 2801 번째 페이지 parsing....
# 2802 번째 페이지 parsing....
# 2803 번째 페이지 parsing....
# 2804 번째 페이지 parsing....
# 2805 번째 페이지 parsing....
# 2806 번째 페이지 parsing....
# ...
# 5135 번째 페이지 parsing....
# 5136 번째 페이지 parsing....
# 5137 번째 페이지 parsing....
# 5138 번째 페이지 parsing....
# 5139 번째 페이지 parsing....
# 5140 번째 페이지 parsing....
# 5141 번째 페이지 parsing....
# 5142 번째 페이지 parsing....
# 5143 번째 페이지 parsing....
# 5144 번째 페이지 parsing....
# 5145 번째 페이지 parsing....
# 5146 번째 페이지 parsing....
# 5147 번째 페이지 parsing....
# 5148 번째 페이지 parsing....
# 5149 번째 페이지 parsing....
# 5150 번째 페이지 parsing....
# 5151 번째 페이지 parsing....
# 5152 번째 페이지 parsing....
# 5153 번째 페이지 parsing....
# 5154 번째 페이지 parsing....
# 5155 번째 페이지 parsing....
# 5156 번째 페이지 parsing....
# 5157 번째 페이지 parsing....
# 5158 번째 페이지 parsing....
# 5159 번째 페이지 parsing....
# 5160 번째 페이지 parsing....
# 5161 번째 페이지 parsing....
# 5162 번째 페이지 parsing....
# 5163 번째 페이지 parsing....
# 5164 번째 페이지 parsing....
# 5165 번째 페이지 parsing....
# 5166 번째 페이지 parsing....
# 5167 번째 페이지 parsing....
# 5168 번째 페이지 parsing....
# 5169 번째 페이지 parsing....
# 5170 번째 페이지 parsing....
# 5171 번째 페이지 parsing....
# 5172 번째 페이지 parsing....
# 5173 번째 페이지 parsing....
# 5174 번째 페이지 parsing....
# 5175 번째 페이지 parsing....
# 5176 번째 페이지 parsing....
# 5177 번째 페이지 parsing....
# 5178 번째 페이지 parsing....
# 5179 번째 페이지 parsing....
# 5180 번째 페이지 parsing....
# 5181 번째 페이지 parsing....
# 5182 번째 페이지 parsing....
# 5183 번째 페이지 parsing....
# 5184 번째 페이지 parsing....
# 5185 번째 페이지 parsing....
# 5186 번째 페이지 parsing....
# 5187 번째 페이지 parsing....
# 5188 번째 페이지 parsing....
# 5189 번째 페이지 parsing....
# 5190 번째 페이지 parsing....
# 5191 번째 페이지 parsing....
# 5192 번째 페이지 parsing....
# 5193 번째 페이지 parsing....
# 5194 번째 페이지 parsing....
# 5195 번째 페이지 parsing....
# 5196 번째 페이지 parsing....
# 5197 번째 페이지 parsing....
# 5198 번째 페이지 parsing....
# 5199 번째 페이지 parsing....
# 5200 번째 페이지 parsing....
# 5201 번째 페이지 parsing....
# 5202 번째 페이지 parsing....
# 5203 번째 페이지 parsing....
# 5204 번째 페이지 parsing....
# 5205 번째 페이지 parsing....
# 5206 번째 페이지 parsing....
# 5207 번째 페이지 parsing....
# 5208 번째 페이지 parsing....
# 5209 번째 페이지 parsing....
# 5210 번째 페이지 parsing....
# 5211 번째 페이지 parsing....
# 5212 번째 페이지 parsing....
# 5213 번째 페이지 parsing....
# 5214 번째 페이지 parsing....
# 5215 번째 페이지 parsing....
# 5216 번째 페이지 parsing....
# 5217 번째 페이지 parsing....
# 5218 번째 페이지 parsing....
# 5219 번째 페이지 parsing....
# 5220 번째 페이지 parsing....
# 5221 번째 페이지 parsing....
# 5222 번째 페이지 parsing....
# 5223 번째 페이지 parsing....
# 5224 번째 페이지 parsing....
# 5225 번째 페이지 parsing....
# 5226 번째 페이지 parsing....
# 5227 번째 페이지 parsing....
# 5228 번째 페이지 parsing....
# 5229 번째 페이지 parsing....
# 5230 번째 페이지 parsing....
# 5231 번째 페이지 parsing....
# 5232 번째 페이지 parsing....
# 5233 번째 페이지 parsing....
# 5234 번째 페이지 parsing....
# 5235 번째 페이지 parsing....
# 5236 번째 페이지 parsing....
# 5237 번째 페이지 parsing....
# 5238 번째 페이지 parsing....
# 5239 번째 페이지 parsing....
# 5240 번째 페이지 parsing....
# 5241 번째 페이지 parsing....
# 5242 번째 페이지 parsing....
# 5243 번째 페이지 parsing....
# 5244 번째 페이지 parsing....
# 5245 번째 페이지 parsing....
# 5246 번째 페이지 parsing....
# 5247 번째 페이지 parsing....
# 5248 번째 페이지 parsing....
# 5249 번째 페이지 parsing....
# 5250 번째 페이지 parsing....
# 5251 번째 페이지 parsing....
# 5252 번째 페이지 parsing....
# 5253 번째 페이지 parsing....
# 5254 번째 페이지 parsing....
# 5255 번째 페이지 parsing....
# 5256 번째 페이지 parsing....
# 5257 번째 페이지 parsing....
# 5258 번째 페이지 parsing....
# 5259 번째 페이지 parsing....
# 5260 번째 페이지 parsing....
# 5261 번째 페이지 parsing....
# 5262 번째 페이지 parsing....
# 5263 번째 페이지 parsing....
# 5264 번째 페이지 parsing....
# 5265 번째 페이지 parsing....
# 5266 번째 페이지 parsing....
# 5267 번째 페이지 parsing....
# 5268 번째 페이지 parsing....
# 5269 번째 페이지 parsing....
# 5270 번째 페이지 parsing....
# 5271 번째 페이지 parsing....
# 5272 번째 페이지 parsing....
# 5273 번째 페이지 parsing....
# 5274 번째 페이지 parsing....
# 5275 번째 페이지 parsing....
# 5276 번째 페이지 parsing....
# 5277 번째 페이지 parsing....
# 5278 번째 페이지 parsing....
# 5279 번째 페이지 parsing....
# 5280 번째 페이지 parsing....
# 5281 번째 페이지 parsing....
# 5282 번째 페이지 parsing....
# 5283 번째 페이지 parsing....
# 5284 번째 페이지 parsing....
# 5285 번째 페이지 parsing....
# 5286 번째 페이지 parsing....
# 5287 번째 페이지 parsing....
# 5288 번째 페이지 parsing....
# 5289 번째 페이지 parsing....
# 5290 번째 페이지 parsing....
# 5291 번째 페이지 parsing....
# 5292 번째 페이지 parsing....
# 5293 번째 페이지 parsing....
# 5294 번째 페이지 parsing....
# 5295 번째 페이지 parsing....
# 5296 번째 페이지 parsing....
# 5297 번째 페이지 parsing....
# 5298 번째 페이지 parsing....
# 5299 번째 페이지 parsing....
# 5300 번째 페이지 parsing....
# 5301 번째 페이지 parsing....
# 5302 번째 페이지 parsing....
# 5303 번째 페이지 parsing....
# 5304 번째 페이지 parsing....
# 5305 번째 페이지 parsing....
# 5306 번째 페이지 parsing....
# 5307 번째 페이지 parsing....
# 5308 번째 페이지 parsing....
# 5309 번째 페이지 parsing....
# 5310 번째 페이지 parsing....
# 5311 번째 페이지 parsing....
# 5312 번째 페이지 parsing....
# 5313 번째 페이지 parsing....
# 5314 번째 페이지 parsing....
# 5315 번째 페이지 parsing....
# 5316 번째 페이지 parsing....
# 5317 번째 페이지 parsing....
# 5318 번째 페이지 parsing....
# 5319 번째 페이지 parsing....
# 5320 번째 페이지 parsing....
# 5321 번째 페이지 parsing....
# 5322 번째 페이지 parsing....
# 5323 번째 페이지 parsing....
# 5324 번째 페이지 parsing....
# 5325 번째 페이지 parsing....
# 5326 번째 페이지 parsing....
# 5327 번째 페이지 parsing....
# 5328 번째 페이지 parsing....
# 5329 번째 페이지 parsing....
# 5330 번째 페이지 parsing....
# 5331 번째 페이지 parsing....
# 5332 번째 페이지 parsing....
# 5333 번째 페이지 parsing....
# 5334 번째 페이지 parsing....
# 5335 번째 페이지 parsing....
# 5336 번째 페이지 parsing....
# 5337 번째 페이지 parsing....
# 5338 번째 페이지 parsing....
# 5339 번째 페이지 parsing....
# 5340 번째 페이지 parsing....
# 5341 번째 페이지 parsing....
# 5342 번째 페이지 parsing....
# 5343 번째 페이지 parsing....
# 5344 번째 페이지 parsing....
# 5345 번째 페이지 parsing....
# 5346 번째 페이지 parsing....
# 5347 번째 페이지 parsing....
# 5348 번째 페이지 parsing....
# 5349 번째 페이지 parsing....
# 5350 번째 페이지 parsing....
# 5351 번째 페이지 parsing....
# 5352 번째 페이지 parsing....
# 5353 번째 페이지 parsing....
# 5354 번째 페이지 parsing....
# 5355 번째 페이지 parsing....
# 5356 번째 페이지 parsing....
# 5357 번째 페이지 parsing....
# 5358 번째 페이지 parsing....
# 5359 번째 페이지 parsing....
# 5360 번째 페이지 parsing....
# 5361 번째 페이지 parsing....
# 5362 번째 페이지 parsing....
# 5363 번째 페이지 parsing....
# 5364 번째 페이지 parsing....
# 5365 번째 페이지 parsing....
# 5366 번째 페이지 parsing....
# 5367 번째 페이지 parsing....
# 5368 번째 페이지 parsing....
# 5369 번째 페이지 parsing....
# 5370 번째 페이지 parsing....
# 5371 번째 페이지 parsing....
# 5372 번째 페이지 parsing....
# 5373 번째 페이지 parsing....
# 5374 번째 페이지 parsing....
# 5375 번째 페이지 parsing....
# 5376 번째 페이지 parsing....
# 5377 번째 페이지 parsing....
# 5378 번째 페이지 parsing....
# 5379 번째 페이지 parsing....
# 5380 번째 페이지 parsing....
# 5381 번째 페이지 parsing....
# 5382 번째 페이지 parsing....
# 5383 번째 페이지 parsing....
# 5384 번째 페이지 parsing....
# 5385 번째 페이지 parsing....
# 5386 번째 페이지 parsing....
# 5387 번째 페이지 parsing....
# 5388 번째 페이지 parsing....
# 5389 번째 페이지 parsing....
# 5390 번째 페이지 parsing....
# 5391 번째 페이지 parsing....
# 5392 번째 페이지 parsing....
# 5393 번째 페이지 parsing....
# 5394 번째 페이지 parsing....
# 5395 번째 페이지 parsing....
# 5396 번째 페이지 parsing....
# 5397 번째 페이지 parsing....
# 5398 번째 페이지 parsing....
# 5399 번째 페이지 parsing....
# 5400 번째 페이지 parsing....
# 5401 번째 페이지 parsing....
# 5402 번째 페이지 parsing....
# 5403 번째 페이지 parsing....
# 5404 번째 페이지 parsing....
# 5405 번째 페이지 parsing....
# 5406 번째 페이지 parsing....
# 5407 번째 페이지 parsing....
# 5408 번째 페이지 parsing....
# 5409 번째 페이지 parsing....
# 5410 번째 페이지 parsing....
# 5411 번째 페이지 parsing....
# 5412 번째 페이지 parsing....
# 5413 번째 페이지 parsing....
# 5414 번째 페이지 parsing....
# 5415 번째 페이지 parsing....
# 5416 번째 페이지 parsing....
# 5417 번째 페이지 parsing....
# 5418 번째 페이지 parsing....
# 5419 번째 페이지 parsing....
# 5420 번째 페이지 parsing....
# 5421 번째 페이지 parsing....
# 5422 번째 페이지 parsing....
# 5423 번째 페이지 parsing....
# 5424 번째 페이지 parsing....
# 5425 번째 페이지 parsing....
# 5426 번째 페이지 parsing....
# 5427 번째 페이지 parsing....
# 5428 번째 페이지 parsing....
# 5429 번째 페이지 parsing....
# 5430 번째 페이지 parsing....
# 5431 번째 페이지 parsing....
# 5432 번째 페이지 parsing....
# 5433 번째 페이지 parsing....
# 5434 번째 페이지 parsing....
# 5435 번째 페이지 parsing....
# 5436 번째 페이지 parsing....
# 5437 번째 페이지 parsing....
# 5438 번째 페이지 parsing....
# 5439 번째 페이지 parsing....
# 5440 번째 페이지 parsing....
# 5441 번째 페이지 parsing....
# 5442 번째 페이지 parsing....
# 5443 번째 페이지 parsing....
# 5444 번째 페이지 parsing....
# 5445 번째 페이지 parsing....
# 5446 번째 페이지 parsing....
# 5447 번째 페이지 parsing....
# 5448 번째 페이지 parsing....
# 5449 번째 페이지 parsing....
# 5450 번째 페이지 parsing....
# 5451 번째 페이지 parsing....
# 5452 번째 페이지 parsing....
# 5453 번째 페이지 parsing....
# 5454 번째 페이지 parsing....
# 5455 번째 페이지 parsing....
# 5456 번째 페이지 parsing....
# 5457 번째 페이지 parsing....
# 5458 번째 페이지 parsing....
# 5459 번째 페이지 parsing....
# 5460 번째 페이지 parsing....
# 5461 번째 페이지 parsing....
# 5462 번째 페이지 parsing....
# 5463 번째 페이지 parsing....
# 5464 번째 페이지 parsing....
# 5465 번째 페이지 parsing....
# 5466 번째 페이지 parsing....
# 5467 번째 페이지 parsing....
# 5468 번째 페이지 parsing....
# 5469 번째 페이지 parsing....
# 5470 번째 페이지 parsing....
# 5471 번째 페이지 parsing....
# 5472 번째 페이지 parsing....
# 5473 번째 페이지 parsing....
# 5474 번째 페이지 parsing....
# 5475 번째 페이지 parsing....
# 5476 번째 페이지 parsing....
# 5477 번째 페이지 parsing....
# 5478 번째 페이지 parsing....
# 5479 번째 페이지 parsing....
# 5480 번째 페이지 parsing....
# 5481 번째 페이지 parsing....
# 5482 번째 페이지 parsing....
# 5483 번째 페이지 parsing....
# 5484 번째 페이지 parsing....
# 5485 번째 페이지 parsing....
# 5486 번째 페이지 parsing....
# 5487 번째 페이지 parsing....
# 5488 번째 페이지 parsing....
# 5489 번째 페이지 parsing....
# 5490 번째 페이지 parsing....
# 5491 번째 페이지 parsing....
# 5492 번째 페이지 parsing....
# 5493 번째 페이지 parsing....
# 5494 번째 페이지 parsing....
# 5495 번째 페이지 parsing....
# 5496 번째 페이지 parsing....
# 5497 번째 페이지 parsing....
# 5498 번째 페이지 parsing....
# 5499 번째 페이지 parsing....
# 5500 번째 페이지 parsing....
# 5501 번째 페이지 parsing....
# 5502 번째 페이지 parsing....
# 5503 번째 페이지 parsing....
# 5504 번째 페이지 parsing....
# 5505 번째 페이지 parsing....
# 5506 번째 페이지 parsing....
# 5507 번째 페이지 parsing....
# 5508 번째 페이지 parsing....
# 5509 번째 페이지 parsing....
# 5510 번째 페이지 parsing....
# 5511 번째 페이지 parsing....
# 5512 번째 페이지 parsing....
# 5513 번째 페이지 parsing....
# 5514 번째 페이지 parsing....
# 5515 번째 페이지 parsing....
# 5516 번째 페이지 parsing....
# 5517 번째 페이지 parsing....
# 5518 번째 페이지 parsing....
# 5519 번째 페이지 parsing....
# 5520 번째 페이지 parsing....
# 5521 번째 페이지 parsing....
# 5522 번째 페이지 parsing....
# 5523 번째 페이지 parsing....
# 5524 번째 페이지 parsing....
# 5525 번째 페이지 parsing....
# 5526 번째 페이지 parsing....
# 5527 번째 페이지 parsing....
# 5528 번째 페이지 parsing....
# 5529 번째 페이지 parsing....
# 5530 번째 페이지 parsing....
# 5531 번째 페이지 parsing....
# 5532 번째 페이지 parsing....
# 5533 번째 페이지 parsing....
# 5534 번째 페이지 parsing....
# 5535 번째 페이지 parsing....
# 5536 번째 페이지 parsing....
# 5537 번째 페이지 parsing....
# 5538 번째 페이지 parsing....
# 5539 번째 페이지 parsing....
# 5540 번째 페이지 parsing....
# 5541 번째 페이지 parsing....
# 5542 번째 페이지 parsing....
# 5543 번째 페이지 parsing....
# 5544 번째 페이지 parsing....
# 5545 번째 페이지 parsing....
# 5546 번째 페이지 parsing....
# 5547 번째 페이지 parsing....
# 5548 번째 페이지 parsing....
# 5549 번째 페이지 parsing....
# 5550 번째 페이지 parsing....
# 5551 번째 페이지 parsing....
# 5552 번째 페이지 parsing....
# 5553 번째 페이지 parsing....
# 5554 번째 페이지 parsing....
# 5555 번째 페이지 parsing....
# 5556 번째 페이지 parsing....
# 5557 번째 페이지 parsing....
# 5558 번째 페이지 parsing....
# 5559 번째 페이지 parsing....
# 5560 번째 페이지 parsing....
# 5561 번째 페이지 parsing....
# 5562 번째 페이지 parsing....
# 5563 번째 페이지 parsing....
# 5564 번째 페이지 parsing....
# 5565 번째 페이지 parsing....
# 5566 번째 페이지 parsing....
# 5567 번째 페이지 parsing....
# 5568 번째 페이지 parsing....
# 5569 번째 페이지 parsing....
# 5570 번째 페이지 parsing....
# 5571 번째 페이지 parsing....
# 5572 번째 페이지 parsing....
# 5573 번째 페이지 parsing....
# 5574 번째 페이지 parsing....
# 5575 번째 페이지 parsing....
# 5576 번째 페이지 parsing....
# 5577 번째 페이지 parsing....
# 5578 번째 페이지 parsing....
# 5579 번째 페이지 parsing....
# 5580 번째 페이지 parsing....
# 5581 번째 페이지 parsing....
# 5582 번째 페이지 parsing....
# 5583 번째 페이지 parsing....
# 5584 번째 페이지 parsing....
# 5585 번째 페이지 parsing....
# 5586 번째 페이지 parsing....
# 5587 번째 페이지 parsing....
# 5588 번째 페이지 parsing....
# 5589 번째 페이지 parsing....
# 5590 번째 페이지 parsing....
# 5591 번째 페이지 parsing....
# 5592 번째 페이지 parsing....
# 5593 번째 페이지 parsing....
# 5594 번째 페이지 parsing....
# 5595 번째 페이지 parsing....
# 5596 번째 페이지 parsing....
# 5597 번째 페이지 parsing....
# 5598 번째 페이지 parsing....
# 5599 번째 페이지 parsing....
# 5600 번째 페이지 parsing....
# 5601 번째 페이지 parsing....
# 5602 번째 페이지 parsing....
# 5603 번째 페이지 parsing....
# 5604 번째 페이지 parsing....
# 5605 번째 페이지 parsing....
# 5606 번째 페이지 parsing....
# 5607 번째 페이지 parsing....
# 5608 번째 페이지 parsing....
# 5609 번째 페이지 parsing....
# 5610 번째 페이지 parsing....
# 5611 번째 페이지 parsing....
# 5612 번째 페이지 parsing....
# 5613 번째 페이지 parsing....
# 5614 번째 페이지 parsing....
# 5615 번째 페이지 parsing....
# 5616 번째 페이지 parsing....
# 5617 번째 페이지 parsing....
# 5618 번째 페이지 parsing....
# 5619 번째 페이지 parsing....
# 5620 번째 페이지 parsing....
# 5621 번째 페이지 parsing....
# 5622 번째 페이지 parsing....
# 5623 번째 페이지 parsing....
# 5624 번째 페이지 parsing....
# 5625 번째 페이지 parsing....
# 5626 번째 페이지 parsing....
# 5627 번째 페이지 parsing....
# 5628 번째 페이지 parsing....
# 5629 번째 페이지 parsing....
# 5630 번째 페이지 parsing....
# 5631 번째 페이지 parsing....
# 5632 번째 페이지 parsing....
# 5633 번째 페이지 parsing....
# 5634 번째 페이지 parsing....
# 5635 번째 페이지 parsing....
# 5636 번째 페이지 parsing....
# 5637 번째 페이지 parsing....
# 5638 번째 페이지 parsing....
# 5639 번째 페이지 parsing....
# 5640 번째 페이지 parsing....
# 5641 번째 페이지 parsing....
# 5642 번째 페이지 parsing....
# 5643 번째 페이지 parsing....
# 5644 번째 페이지 parsing....
# 5645 번째 페이지 parsing....
# 5646 번째 페이지 parsing....
# 5647 번째 페이지 parsing....
# 5648 번째 페이지 parsing....
# 5649 번째 페이지 parsing....
# 5650 번째 페이지 parsing....
# 5651 번째 페이지 parsing....
# 5652 번째 페이지 parsing....
# 5653 번째 페이지 parsing....
# 5654 번째 페이지 parsing....
# 5655 번째 페이지 parsing....
# 5656 번째 페이지 parsing....
# 5657 번째 페이지 parsing....
# 5658 번째 페이지 parsing....
# 5659 번째 페이지 parsing....
# 5660 번째 페이지 parsing....
# 5661 번째 페이지 parsing....
# 5662 번째 페이지 parsing....
# 5663 번째 페이지 parsing....
# 5664 번째 페이지 parsing....
# 5665 번째 페이지 parsing....
# 5666 번째 페이지 parsing....
# 5667 번째 페이지 parsing....
# 5668 번째 페이지 parsing....
# 5669 번째 페이지 parsing....
# 5670 번째 페이지 parsing....
# 5671 번째 페이지 parsing....
# 5672 번째 페이지 parsing....
# 5673 번째 페이지 parsing....
# 5674 번째 페이지 parsing....
# 5675 번째 페이지 parsing....
# 5676 번째 페이지 parsing....
# 5677 번째 페이지 parsing....
# 5678 번째 페이지 parsing....
# 5679 번째 페이지 parsing....
# 5680 번째 페이지 parsing....
# 5681 번째 페이지 parsing....
# 5682 번째 페이지 parsing....
# 5683 번째 페이지 parsing....
# 5684 번째 페이지 parsing....
# 5685 번째 페이지 parsing....
# 5686 번째 페이지 parsing....
# 5687 번째 페이지 parsing....
# 5688 번째 페이지 parsing....
# 5689 번째 페이지 parsing....
# 5690 번째 페이지 parsing....
# 5691 번째 페이지 parsing....
# 5692 번째 페이지 parsing....
# 5693 번째 페이지 parsing....
# 5694 번째 페이지 parsing....
# 5695 번째 페이지 parsing....
# 5696 번째 페이지 parsing....
# 5697 번째 페이지 parsing....
# 5698 번째 페이지 parsing....
# 5699 번째 페이지 parsing....
# 5700 번째 페이지 parsing....
# 5701 번째 페이지 parsing....
# 5702 번째 페이지 parsing....
# 5703 번째 페이지 parsing....
# 5704 번째 페이지 parsing....
# 5705 번째 페이지 parsing....
# 5706 번째 페이지 parsing....
# 5707 번째 페이지 parsing....
# 5708 번째 페이지 parsing....
# 5709 번째 페이지 parsing....
# 5710 번째 페이지 parsing....
# 5711 번째 페이지 parsing....
# 5712 번째 페이지 parsing....
# 5713 번째 페이지 parsing....
# 5714 번째 페이지 parsing....
# 5715 번째 페이지 parsing....
# 5716 번째 페이지 parsing....
# 5717 번째 페이지 parsing....
# 5718 번째 페이지 parsing....
# 5719 번째 페이지 parsing....
# 5720 번째 페이지 parsing....
# 5721 번째 페이지 parsing....
# 5722 번째 페이지 parsing....
# 5723 번째 페이지 parsing....
# 5724 번째 페이지 parsing....
# 5725 번째 페이지 parsing....
# 5726 번째 페이지 parsing....
# 5727 번째 페이지 parsing....
# 5728 번째 페이지 parsing....
# 5729 번째 페이지 parsing....
# 5730 번째 페이지 parsing....
# 5731 번째 페이지 parsing....
# 5732 번째 페이지 parsing....
# 5733 번째 페이지 parsing....
# 5734 번째 페이지 parsing....
# 5735 번째 페이지 parsing....
# 5736 번째 페이지 parsing....
# 5737 번째 페이지 parsing....
# 5738 번째 페이지 parsing....
# 5739 번째 페이지 parsing....
# 5740 번째 페이지 parsing....
# 5741 번째 페이지 parsing....
# 5742 번째 페이지 parsing....
# 5743 번째 페이지 parsing....
# 5744 번째 페이지 parsing....
# 5745 번째 페이지 parsing....
# 5746 번째 페이지 parsing....
# 5747 번째 페이지 parsing....
# 5748 번째 페이지 parsing....
# 5749 번째 페이지 parsing....
# 5750 번째 페이지 parsing....
# 5751 번째 페이지 parsing....
# 5752 번째 페이지 parsing....
# 5753 번째 페이지 parsing....
# 5754 번째 페이지 parsing....
# 5755 번째 페이지 parsing....
# 5756 번째 페이지 parsing....
# 5757 번째 페이지 parsing....
# 5758 번째 페이지 parsing....
# 5759 번째 페이지 parsing....
# 5760 번째 페이지 parsing....
# 5761 번째 페이지 parsing....
# 5762 번째 페이지 parsing....
# 5763 번째 페이지 parsing....
# 5764 번째 페이지 parsing....
# 5765 번째 페이지 parsing....
# 5766 번째 페이지 parsing....
# 5767 번째 페이지 parsing....
# 5768 번째 페이지 parsing....
# 5769 번째 페이지 parsing....
# 5770 번째 페이지 parsing....
# 5771 번째 페이지 parsing....
# 5772 번째 페이지 parsing....
# 5773 번째 페이지 parsing....
# 5774 번째 페이지 parsing....
# 5775 번째 페이지 parsing....
# 5776 번째 페이지 parsing....
# 5777 번째 페이지 parsing....
# 5778 번째 페이지 parsing....
# 5779 번째 페이지 parsing....
# 5780 번째 페이지 parsing....
# 5781 번째 페이지 parsing....
# 5782 번째 페이지 parsing....
# 5783 번째 페이지 parsing....
# 5784 번째 페이지 parsing....
# 5785 번째 페이지 parsing....
# 5786 번째 페이지 parsing....
# 5787 번째 페이지 parsing....
# 5788 번째 페이지 parsing....
# 5789 번째 페이지 parsing....
# 5790 번째 페이지 parsing....
# 5791 번째 페이지 parsing....
# 5792 번째 페이지 parsing....
# 5793 번째 페이지 parsing....
# 5794 번째 페이지 parsing....
# 5795 번째 페이지 parsing....
# 5796 번째 페이지 parsing....
# 5797 번째 페이지 parsing....
# 5798 번째 페이지 parsing....
# 5799 번째 페이지 parsing....
# 5800 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['순수인(kjni****)',
#   '좀비가 무서운게아니라 사람이무섭다는걸 알려주는영화',
#   '10',
#   '19665',
#   '1253',
#   datetime.datetime(2016, 7, 20, 5, 57),
#   0],
#  ['20fh****',
#   '그냥 한국형 좀비물이 어색하지 않았다는 거에 큰 점수를 주며 앞으로의 한국영화를 기대해봅니다.',
#   '10',
#   '14661',
#   '1441',
#   datetime.datetime(2016, 7, 20, 11, 56),
#   '관람객'],
#  ['ㄹㅇㅁㄻㅇ(wjse****)',
#   '버스회사 상무라는 사람이 진심 역대급 민폐캐릭터인듯개짜증나고 생존력도 좋음',
#   '10',
#   '13845',
#   '1061',
#   datetime.datetime(2016, 7, 20, 0, 0),
#   0],
#  ['kpl(lkp7****)',
#   '생각보다 너무 재밌었다',
#   '10',
#   '12450',
#   '1950',
#   datetime.datetime(2016, 7, 20, 1, 11),
#   '관람객'],
#  ['쥘(sgre****)',
#   '영화가 너무 비현실적이네요. 예를들어 공유 얼굴이라던가 공유 얼굴 같은 부분이...',
#   '6',
#   '12594',
#   '2539',
#   datetime.datetime(2016, 7, 20, 7, 30),
#   0],
#  ['살모(ooas****)',
#   '마동석 진짜 웃겨요 사랑해요',
#   '10',
#   '9971',
#   '493',
#   datetime.datetime(2016, 7, 20, 16, 29),
#   '관람객'],
#  ['ㅇㅇㅇㅇ(yuha****)',
#   '배급사는 스포일러 법적대응 해야할듯',
#   '8',
#   '9557',
#   '880',
#   datetime.datetime(2016, 7, 20, 0, 45),
#   0],
#  ['hesu****',
#   '한국에서 볼 수 없었던 영화',
#   '9',
#   '8830',
#   '982',
#   datetime.datetime(2016, 7, 20, 0, 21),
#   '관람객'],
#  ['다빵씨(ddaz****)',
#   '심은경 열연 감동했어요.',
#   '5',
#   '5976',
#   '769',
#   datetime.datetime(2016, 7, 20, 13, 28),
#   '관람객'],
#  ['수취인불명(sksd****)',
#   '그냥 스릴러로 즐기기에 나쁘진 않다, 다만 초반에 어떻게 좀비가 생겼고 현재 전국상황이 어떤지 거의 나오지 않았고, 마지막에 뜬금없는 회상씬은 오그라들게 만들고, 부산에 가서 그냥 끝나버리고 다른 지역의 상황과 앞으...',
#   '6',
#   '9080',
#   '4431',
#   datetime.datetime(2016, 7, 20, 10, 38),
#   0],
#  ['쿠텐탁(yeih****)',
#   '이 영화의 깨알 코미디신은 소희의발연기....관객들이 몰입해서 보다가 하나가되어 웃었다...',
#   '7',
#   '7880',
#   '3362',
#   datetime.datetime(2016, 7, 20, 6, 29),
#   0],
#  ['띵똥(yykj****)',
#   '재밌네요!추천!전 지루하지않고 재밌게 봣습니다',
#   '10',
#   '4300',
#   '743',
#   datetime.datetime(2016, 7, 20, 0, 40),
#   '관람객'],
#  ['bjj0****',
#   '처음 좀비나왔을때는 유치할꺼라 생각했는데 보는내내 재밌고 시간가는줄 몰랐어요',
#   '8',
#   '3603',
#   '562',
#   datetime.datetime(2016, 7, 20, 7, 5),
#   '관람객'],
#  ['0118(roti****)',
#   '고속버스 사장 아재도 발암이지만 난 꼬맹이가 더 발암이었다.. 고구마 392838493327382박스 먹은 기분',
#   '7',
#   '4667',
#   '1667',
#   datetime.datetime(2016, 7, 20, 9, 10),
#   0],
#  ['Sol쏠(574a****)',
#   '재난영화에서 언제까지 여성은 연약하고 수동적이어야만 하나',
#   '8',
#   '5377',
#   '2476',
#   datetime.datetime(2016, 7, 20, 18, 46),
#   '관람객'],
#  ['아지뱀(yhoc****)',
#   '과도한 변칙 개봉 (유료 시사회) 때문에 스포일러가 좀비처럼 퍼졌다.',
#   '6',
#   '3413',
#   '531',
#   datetime.datetime(2016, 7, 20, 0, 6),
#   0],
#  ['성호진(sorb****)',
#   '영화에 온전히 몰입하기엔 생각보다 연기력이 아쉬운 몇몇사람들..',
#   '5',
#   '3985',
#   '1270',
#   datetime.datetime(2016, 7, 20, 12, 33),
#   '관람객'],
#  ['프시카(whrl****)',
#   '좀비물인데 15세라 별거없겠지 하고 보러갔는데나름 위압감있는 좀비의 공세에  놀랐습니다.물론 장기파티도 안나오고 다소 진부한 전개와 한국전통의 가족애는 여전하지만 잘 뽑힌 좀비영화내요.그나저나 꼰대 한놈 때문에 몇명...',
#   '8',
#   '2969',
#   '319',
#   datetime.datetime(2016, 7, 20, 12, 8),
#   '관람객'],
#  ['Vlrxbon(ledb****)',
#   '안소희 뭐냐 ㅡㅡ 영화에는 영화배우를 써라 좀',
#   '1',
#   '6609',
#   '4167',
#   datetime.datetime(2016, 7, 20, 7, 46),
#   0],
#  ['동그라미(kkky****)',
#   '소희...연기하지망',
#   '1',
#   '4544',
#   '2373',
#   datetime.datetime(2016, 7, 20, 8, 46),
#   0],
#  ['이창훈(wowl****)',
#   '초반엔 고속질주 후반엔 급브레이크',
#   '6',
#   '2654',
#   '590',
#   datetime.datetime(2016, 7, 20, 5, 36),
#   '관람객'],
#  ['sandy(sand****)',
#   '시나리오를 진짜 정말 하 어떻게 이렇게 쓰지 공유 마지막에 분유 광고 찍는줄',
#   '1',
#   '2662',
#   '799',
#   datetime.datetime(2016, 7, 20, 22, 47),
#   0],
#  ['박이(jggm****)',
#   '이영화 최악의 빌런은 할머니다',
#   '1',
#   '3050',
#   '1232',
#   datetime.datetime(2016, 7, 20, 6, 37),
#   0],
#  ['마블의 세상(kiss****)',
#   '시사회 때 본 네티즌들은 어느정도 공감할 것이다 여자 꼬마 아이의 쓸데없는 오지랖이 영화의 전체적인 스토리와 흥미를 다 말아 먹었다는 것을',
#   '1',
#   '3123',
#   '1342',
#   datetime.datetime(2016, 7, 20, 8, 3),
#   0],
#  ['벌레깝충(abcd****)',
#   '소희야 우리 다시 노래하자. 노래도 못하지만 그못하는게 더 매력적이다',
#   '1',
#   '2655',
#   '976',
#   datetime.datetime(2016, 7, 20, 11, 58),
#   0],
#  ['SORYPHONE(sory****)',
#   '이런류 영화 좋아요 아주아주',
#   '8',
#   '2094',
#   '456',
#   datetime.datetime(2016, 7, 20, 0, 55),
#   '관람객'],
#  ['집합소(soph****)',
#   '감독님 찍다가 중반에 좀비되신건가요 왜 중반까지는 재밌었는데 당황스러운 스토리와 신파로 영화를 다 망치셨는지...',
#   '4',
#   '2350',
#   '826',
#   datetime.datetime(2016, 7, 20, 7, 16),
#   0],
#  ['17K(fks6****)',
#   '다른사람들은 재미없다는데 난너무재밌음ㅋㅋ또보고싶다ㅋ',
#   '10',
#   '1882',
#   '451',
#   datetime.datetime(2016, 7, 20, 16, 58),
#   '관람객'],
#  ['돈까스(kcjs****)',
#   '기차 갈아탈때  밑으로 넘어갔으면 다살았다 글고 임산부 아주머님 달리기 육상선수 수준',
#   '1',
#   '1643',
#   '233',
#   datetime.datetime(2016, 7, 20, 22, 16),
#   0],
#  ['정유경(dlqk****)',
#   '영화 보는 내내 긴장의 끈을 놓을 수가 없었고.. 마지막엔 슬퍼서 눈물 쪼꼼 났어요..ㅜ',
#   '9',
#   '1788',
#   '479',
#   datetime.datetime(2016, 7, 20, 13, 17),
#   '관람객'],
#  ['꿈꾸는하늘(suni****)',
#   '진짜 깔게 너무 많아서..일단 OST..머냐?스토리 뚝뚝.내용과도 전혀 어울리지 않는.15세라 좀비를 맨주먹으로 때려부수고 유리창하나면 방어끝?왜 바이러스가 퍼졋는지?부산까지 가는 2시간동안 전국이 어떻게 감염됨?소...',
#   '1',
#   '2768',
#   '1468',
#   datetime.datetime(2016, 7, 20, 8, 25),
#   0],
#  ['나로(cjs3****)',
#   '쌍팔년도 스타일...한번넘어지면 바로안일어나고 3초씩밍기적대고 인도영화랑 비슷함..초딩은 애늙이멘트치고 어른들 훈계함 대사가 대체로 아침드라마 같은 진부한 멘트..배경음악도 80년대음악같음. 결말도 억지감동..이거잼...',
#   '1',
#   '2026',
#   '766',
#   datetime.datetime(2016, 7, 20, 12, 32),
#   0],
#  ['덩구탕(u2u4****)',
#   '아역배우랑 소희의 연기력이 아쉽네요.결말도 허무하구요.',
#   '6',
#   '2514',
#   '1313',
#   datetime.datetime(2016, 7, 20, 11, 42),
#   '관람객'],
#  ['아이테인(ches****)',
#   '후반부에 부자연스러움 그자체',
#   '1',
#   '1692',
#   '607',
#   datetime.datetime(2016, 7, 20, 6, 9),
#   0],
#  ['긔옇(rlsm****)',
#   'Kt 여승무원을  소희역 시키지  훨 이쁘고 연기도 잘하든데 난친구가 못가서 대신보고온건데..이영화 배우들 한테 연기상 줄려거든좀비들 한테 주길',
#   '6',
#   '1200',
#   '146',
#   datetime.datetime(2016, 7, 20, 11, 24),
#   0],
#  ['레종(cgy7****)',
#   '아 존나 신선했는데 짜증나고 답답한 느낌이 가실질 않는다 이걸노렸나?',
#   '2',
#   '1383',
#   '337',
#   datetime.datetime(2016, 7, 20, 10, 34),
#   0],
#  ['김은초(qpzz****)',
#   '기대없이 봐서 재밌게 봤어요 영화내용이 이런 사건이 생긴 이유나 해결방법 등 전혀 없이 그냥 계속 쫓기고 죽다가 끝나서 조금 허무하긴 하지만 스릴넘치네요',
#   '5',
#   '1318',
#   '275',
#   datetime.datetime(2016, 7, 20, 11, 55),
#   '관람객'],
#  ['hyoy****',
#   '마지막 아이의 노래를 듣는순간 짜증나서 내가 좀비로 변할것 같았다',
#   '1',
#   '2671',
#   '1652',
#   datetime.datetime(2016, 7, 20, 21, 43),
#   '관람객'],
#  ['일박(qkrt****)',
#   '원래 sf나 좀비 같은 실제하지않는 허구의 영화를 좋아해서 별점은 높다. 실제로 영화도 재밌다. 그러나 아쉬운건 영화 초반 감염경로나 마지막 결말부분이 너무 부족한게아닌가...',
#   '9',
#   '1190',
#   '176',
#   datetime.datetime(2016, 7, 20, 15, 24),
#   '관람객'],
#  ['Svon(1993****)',
#   '꼭 조연들은 물리면 일초만에 좀비되고 주요인물들은 하루 죙일 감정잡다 적당한 타이밍에 변하냐? 그 외에도 좀비들이 달리는 기차에 뭉텅이로 매달리질 않나 갑자기 불타서 선로막는 기차에 코미디 수준 ㅋㅋ',
#   '1',
#   '1304',
#   '418',
#   datetime.datetime(2016, 7, 22, 0, 33),
#   '관람객'],
#  ['밀루유떼(kjhn****)',
#   '이성적인 판단이 가능한 사람은 내 별점 공감할것이다',
#   '1',
#   '1449',
#   '569',
#   datetime.datetime(2016, 7, 20, 11, 37),
#   0],
#  ['요요(tj91****)',
#   '솔직히 코믹이였다(코믹이 맞다면 7점) 마동석캐리여서 5점 특히 문제점 소희(응원단)우식이랑(야구부)통화하는 장면 심각해야되는 장면인데 관객들이 다 웃었다 분명 슬픈장면인데 그럴의도로 찍은 장면이 아닐텐데 킬링타임으...',
#   '5',
#   '1150',
#   '276',
#   datetime.datetime(2016, 7, 20, 2, 0),
#   0],
#  ['NeonFerrari(neon****)',
#   '이건 마동석이 주인공이다',
#   '2',
#   '1041',
#   '182',
#   datetime.datetime(2016, 7, 21, 6, 52),
#   '관람객'],
#  ['장타한방(aju1****)',
#   '제발 할머니역은 진짜 할머니 좀 써라.관객들 우롱하는것도 아니고 어색한할머니 분장으로 진짜 욕나올뻔했고 아역배우 극암유발 연기와 소희 로보트연기에 진짜 자리에 앉아있기도 싫더라.',
#   '1',
#   '964',
#   '108',
#   datetime.datetime(2016, 7, 22, 4, 42),
#   0],
#  ['영소남(zjvl****)',
#   '그놈의 스포일러만 안떴어도..',
#   '8',
#   '1108',
#   '260',
#   datetime.datetime(2016, 7, 20, 0, 15),
#   0],
#  ['나팔소리(ant3****)',
#   '마동석 없었으면 망했을 영화다..그리고 아역 남자인지 여자인지 애매한 캐릭터 써서 영화내내 집중 안되더라..왜 남자같이 생긴 여자애를 썼는지 원..소희는 연기가 참 어색해서 손발이 오글오글..',
#   '1',
#   '2692',
#   '1865',
#   datetime.datetime(2016, 7, 20, 5, 51),
#   0],
#  ['김형준(govl****)',
#   '이게 월드워z보다 평론가평점이 높네?',
#   '1',
#   '1226',
#   '408',
#   datetime.datetime(2016, 7, 20, 10, 40),
#   0],
#  ['추남히(s2cu****)',
#   '소희 연기에 깜짝놀랐고 공유 울음에 칸을 의심했다 억지 감동을 주려하고 사람들의 감정 묘사도 그렇게 잘 된 것 같지않음 ...마동석이 주연인줄',
#   '6',
#   '1150',
#   '356',
#   datetime.datetime(2016, 7, 20, 10, 44),
#   0],
#  ['오두막(dese****)',
#   '좀비가 나오는 재난영화의 완성도가 이 정도까지라는 점이 굉장히 놀랍다. 재미있게 잘 봤다.',
#   '9',
#   '1009',
#   '275',
#   datetime.datetime(2016, 7, 20, 12, 5),
#   '관람객'],
#  ['ㅁㄶㅁㄴㅇ(wjsw****)',
#   '기대하고봤는데 재미하나도 없어요 아역배우랑 안소희씨 너무 안어울리고 영화에 너무 뜬금없는 감성팔이가 많아요',
#   '1',
#   '1430',
#   '709',
#   datetime.datetime(2016, 7, 20, 9, 46),
#   0],
#  ['hyh7****',
#   '할머니 분장 어설퍼ㅡㅡ 아역,  소희 연기력에 이게 영화인지 예능인지...이 영화에 마동석, 정유미가 아깝다',
#   '1',
#   '831',
#   '118',
#   datetime.datetime(2016, 7, 21, 17, 52),
#   0],
#  ['dmsg****',
#   '신파는 좀 뺐으면 합니다..',
#   '8',
#   '855',
#   '182',
#   datetime.datetime(2016, 7, 20, 13, 21),
#   '관람객'],
#  ['캡쿠(qua_****)',
#   '후반부가 허무했어요.',
#   '6',
#   '962',
#   '289',
#   datetime.datetime(2016, 7, 20, 13, 0),
#   '관람객'],
#  ['신드롬(susp****)',
#   '좀비 분장은 훌륭했다. 그러나 이것이 그나마 칭찬할 수 있는 부분. 좀비물에서 가장 중요한 좀비들의 일관성이 부족. 긴장감과 유머, 공포, 감동 모든 것을 넣어보려했으나 연출과 시나리오의 한계로 오히려 주의가 산만해...',
#   '6',
#   '946',
#   '282',
#   datetime.datetime(2016, 7, 20, 8, 21),
#   0],
#  ['si44****',
#   '신파가 영화를 망쳤다. 공유의 분유광고는 덤.',
#   '3',
#   '870',
#   '227',
#   datetime.datetime(2016, 7, 20, 23, 53),
#   '관람객'],
#  ['인간인사람(kyn0****)',
#   '소희야연기는하지말자..ㅎㅎ',
#   '1',
#   '914',
#   '296',
#   datetime.datetime(2016, 7, 20, 16, 39),
#   0],
#  ['qusd****',
#   '박평식 돈먹은거아니야? 다크나이트로 욕쳐먹더니 이제 아주 정신줄을 놨구나  이게어째서 7점짜리영화냐  안소희  넌 두번다시는  영화하지말았으면 한다',
#   '1',
#   '785',
#   '298',
#   datetime.datetime(2016, 7, 20, 10, 27),
#   0],
#  ['큐티울프(kiss****)',
#   '이건뭐~미처가지고 조기개봉은 왜해가지고 온사방 스포질이냐~~',
#   '6',
#   '609',
#   '132',
#   datetime.datetime(2016, 7, 20, 9, 26),
#   0],
#  ['hell****',
#   '좀비가 한국에 오면 ㅈ되는거야 아주 ㅈ되는거지',
#   '7',
#   '615',
#   '142',
#   datetime.datetime(2016, 7, 20, 11, 26),
#   '관람객'],
#  ['jhle****',
#   '뻔한 전개에 뻔한 스토리, 그리고 그놈의 억지 감성팔이...이런 식의 영화만 계속 나오면 대한민국 영화는 발전이 없다',
#   '1',
#   '660',
#   '197',
#   datetime.datetime(2016, 7, 20, 9, 37),
#   0],
#  ['doog****',
#   "'감기' '연가시' '해운대' 와  내용과 결말이 똑같다.",
#   '1',
#   '642',
#   '180',
#   datetime.datetime(2016, 7, 20, 12, 4),
#   0],
#  ['wlal****',
#   '생존자발생!! 엔딩크레딧 이건뭐죠?',
#   '5',
#   '550',
#   '93',
#   datetime.datetime(2016, 7, 20, 10, 37),
#   0],
#  ['qlgu****',
#   '후반부  에  억지스러움 이  있었음  ,,',
#   '6',
#   '661',
#   '204',
#   datetime.datetime(2016, 7, 20, 11, 28),
#   '관람객'],
#  ['인식님ㅋ(dlst****)',
#   '스토리전개가 너무 엉망이다 참고하고 보세요',
#   '1',
#   '728',
#   '310',
#   datetime.datetime(2016, 7, 20, 8, 9),
#   0],
#  ['별날이(rmst****)',
#   '정말 아무것도 없고 텅텅 빈 영화. 근거없는 감염에 부산으로 튀엇! 이게 스토리 끝. 그 속에 넣은 부자연스러운 가족애. 조조로 봤지만 돈아까운 영화.',
#   '1',
#   '582',
#   '170',
#   datetime.datetime(2016, 7, 20, 14, 31),
#   0],
#  ['hackerksh(on80****)',
#   '[월드워Z]의 좀비와 발암선동질 [미스트]를 섞어논 짬뽕작.한국의 좀비라는 신선한?시도는 했지만 영화내용중 꼬마의 오지랖과 위기상황마다 멀뚱멀뚱  쳐다보는 장면이 1~2번 나오는것도 아닌 매순간마다  나옴. 이게 재...',
#   '1',
#   '790',
#   '378',
#   datetime.datetime(2016, 7, 21, 10, 10),
#   '관람객'],
#  ['윤보리(yoon****)',
#   '관람객입니다. 태어나서 이런 후기 처음써보는데 정말 애국심,팬심 다버리고 적날하게씀. 아역,아역이부르는노래,스토리,전개,안소희 <- 진짜 다음날 눈떴는데도 미치게만듬...좀비왜생긴지,해결은어떻게된건지,아역이부르...',
#   '1',
#   '483',
#   '110',
#   datetime.datetime(2016, 7, 21, 9, 57),
#   0],
#  ['jtyjyhgee(qpal****)',
#   '진짜 마동석말고는 하....스토리라는게 없고 허구한날 눈물찔찔하려고 만든영화',
#   '1',
#   '656',
#   '300',
#   datetime.datetime(2016, 7, 21, 1, 36),
#   '관람객'],
#  ['응앵이(bubu****)',
#   '왜 칸느에서 기립박수를쳤는지 전혀이해가 가지않는다',
#   '1',
#   '711',
#   '364',
#   datetime.datetime(2016, 7, 20, 12, 52),
#   '관람객'],
#  ['toto(sssk****)',
#   '마동석 없으면 망할 영화... 영화을 제대로 만들고 스포 신고하던가해라 배우들 연기에 할밀이 없다',
#   '1',
#   '457',
#   '123',
#   datetime.datetime(2016, 7, 20, 12, 59),
#   0],
#  ['국민스타강민호(happ****)',
#   '할머니자매 개그프로그램에 나오는 할머니분장한 사람같더라..',
#   '7',
#   '343',
#   '16',
#   datetime.datetime(2016, 7, 20, 23, 39),
#   0],
#  ['wjdw****',
#   '그냥 신파를  빼면  안되나?   흥행할려구  전작과 다르게 너무  애쓴다',
#   '1',
#   '512',
#   '198',
#   datetime.datetime(2016, 7, 20, 3, 28),
#   0],
#  ['pjse****',
#   '그닥... 군바리들 불쌍해 ㅜ 군대가서 감염 당했는데 거따가 마동석을 뿌려?',
#   '1',
#   '503',
#   '193',
#   datetime.datetime(2016, 7, 20, 22, 28),
#   '관람객'],
#  ['ekgm****',
#   '다들 알바인가요. 세상에 아주 재미없습니다. 진짜 나가려다 참았다. 마동석하드캐리영화.',
#   '1',
#   '678',
#   '368',
#   datetime.datetime(2016, 7, 20, 10, 0),
#   0],
#  ['powe****',
#   '그냥  흥행요소를 집어넣어서 , 장르영화의 특성을 말아먹었네... 신파, 뜨는 배우, 꼼수의 끝판왕 변칙개봉',
#   '1',
#   '484',
#   '205',
#   datetime.datetime(2016, 7, 20, 3, 31),
#   0],
#  ['brucelee(dbsd****)',
#   '내용이 억지가 너무 심함.',
#   '1',
#   '410',
#   '137',
#   datetime.datetime(2016, 7, 20, 1, 44),
#   0],
#  ['문(kks1****)',
#   '암걸리고 더러운인간성을 많이뿌려놓고 어느정도회수해야되는데,,,볼수록 기분안좋아집니다 ,',
#   '1',
#   '432',
#   '160',
#   datetime.datetime(2016, 7, 21, 1, 23),
#   '관람객'],
#  ['sss3****',
#   '마동석의 우리딸 이름.. 가슴이 찡했다',
#   '10',
#   '297',
#   '50',
#   datetime.datetime(2016, 7, 20, 22, 39),
#   '관람객'],
#  ['루나레나(twon****)',
#   '호감순 평점을 믿어라. 왜 1점이 많은지를. 알바에 속지말라.',
#   '1',
#   '350',
#   '103',
#   datetime.datetime(2016, 7, 20, 12, 6),
#   0],
#  ['Jerry Maguire(rams****)',
#   '다크나이트에 7점 준 박평식이 7점이란다ㅋㅋㅋ 그냥 정치적 취향만 맞으면 밀어주는 집단광기는 평론가라고 다를게 없는걸까? 일단 7로 맞춰두고 몇시간뒤 보고와서 수정한다',
#   '7',
#   '387',
#   '146',
#   datetime.datetime(2016, 7, 20, 2, 3),
#   0],
#  ['rlal****',
#   '솔직히나는전설이다 레지던트이블 좀비보다가이거보니깐 스토리도없고 개연성도부족하고그냥 좀비되서 도망가는것뿐..',
#   '1',
#   '387',
#   '149',
#   datetime.datetime(2016, 7, 20, 10, 32),
#   0],
#  ['BDD(siye****)',
#   '소재만 신선했던... 나머지는 모두 엉망진창에 유치한 클리셰',
#   '1',
#   '327',
#   '91',
#   datetime.datetime(2016, 7, 20, 10, 56),
#   0],
#  ['타격기계손아섭(jskw****)',
#   '한국판 좀비영화임...노력은 가상하나 영화관에서 볼 정도는 아니고 명절때 티비로 보는 영화임ㅋㅋㅋ',
#   '3',
#   '373',
#   '142',
#   datetime.datetime(2016, 7, 20, 9, 12),
#   0],
#  ['헬조선노예(ferb****)',
#   '좀비 매니아는 절대 보면 안되는 영화',
#   '1',
#   '349',
#   '122',
#   datetime.datetime(2016, 7, 20, 7, 40),
#   0],
#  ['Hittolife(hitt****)',
#   '다른건 다 그렇다 해도 공유가 마지막에 좀비입에다 손 넣는 것 너무 억지였다. 좀비가 되고 싶어 환장한줄',
#   '1',
#   '258',
#   '34',
#   datetime.datetime(2016, 7, 21, 9, 6),
#   0],
#  ['공부중(dnqh****)',
#   '우리나라영화는뻔하지 국뽕, 억지감동, 가족스토리',
#   '1',
#   '288',
#   '85',
#   datetime.datetime(2016, 7, 20, 8, 18),
#   0],
#  ['멋진놈(jspa****)',
#   '참 뭐라평을 해야할지 모르겠네요  그저 보는내내 답답했읍니다',
#   '1',
#   '405',
#   '204',
#   datetime.datetime(2016, 7, 20, 23, 33),
#   '관람객'],
#  ['즐거운(a333****)',
#   '하하하하공유잘생겼다',
#   '1',
#   '274',
#   '75',
#   datetime.datetime(2016, 7, 21, 20, 46),
#   '관람객'],
#  ['마작(supe****)',
#   "'쾌속의 감흥에서 신파의 터널로' 박평식 한 줄 평이 딱 맞는다. 잘 팔리게 만드느라 아쉬워진 영화.",
#   '7',
#   '268',
#   '74',
#   datetime.datetime(2016, 7, 20, 16, 1),
#   '관람객'],
#  ['김태환(comt****)',
#   '예고편이 전부에요 비추입니다 보지마세요',
#   '1',
#   '390',
#   '197',
#   datetime.datetime(2016, 7, 20, 11, 11),
#   0],
#  ['euji****',
#   '월드워Z나 워킹데드처럼은 기대도 안했다, 약간의 기대는 안드로 메다간듯--',
#   '1',
#   '375',
#   '186',
#   datetime.datetime(2016, 7, 20, 10, 0),
#   0],
#  ['허허(hima****)',
#   '킬링타임용도 안됨 뜬금없는 상황에 뜬금없는 대사 뜬금없는 울음과 음악 아 이거보려고 아침일찍 영화관 간게 후회된다',
#   '1',
#   '245',
#   '72',
#   datetime.datetime(2016, 7, 20, 10, 58),
#   0],
#  ['계구리(blen****)',
#   '차라리 집에서 새벽의저주를 한번 더봐라..',
#   '1',
#   '259',
#   '86',
#   datetime.datetime(2016, 7, 20, 12, 48),
#   0],
#  ['푸른초록꿈(wooj****)',
#   '좀비영화 부산행은 처음시작할때 원인이 불명확한 바이러스가  확인 안된점과 급속도로 퍼지는 좀비들이 인간세상에 던진 이유가 없고. 좀비퇴치 결과가 너무 미흡해서 스릴도 약하고 코믹도 섞여 인기없다고봅니다.',
#   '2',
#   '336',
#   '164',
#   datetime.datetime(2016, 7, 20, 20, 10),
#   '관람객'],
#  ['개성상인(fdc1****)',
#   '보면서 계속 시계 봤네요...',
#   '1',
#   '295',
#   '128',
#   datetime.datetime(2016, 7, 20, 10, 39),
#   0],
#  ['arrowhead(arro****)',
#   '난 잔혹한 좀비물을 보러왔지 휴머니즘을 앞세운 감동영화를 보려온게 아니다.',
#   '1',
#   '296',
#   '133',
#   datetime.datetime(2016, 7, 20, 11, 31),
#   0],
#  ['아도니스(kil1****)',
#   '좀비만보다 끝   내용도없고',
#   '7',
#   '358',
#   '202',
#   datetime.datetime(2016, 7, 20, 12, 1),
#   '관람객'],
#  ['김예안(doe0****)',
#   '딱 5분 고라니가 치여서 비보잉하며 일어날때까진 좋았다 그 후 110분간 주구장창 좀비의 크어어어엉을 듣다가 축농증가능성이 농후한 아이의 노래를 들으며 끝나버렸다. 일단 좀비 발생과 확산 과정등 필요한 장면이 모두 ...',
#   '1',
#   '164',
#   '11',
#   datetime.datetime(2016, 7, 22, 0, 32),
#   0],
#  ['Nina(love****)',
#   '소희 연기 형편 없었고 제발 소희가 빨리 감염돼서 프레임 아웃을 바랐다. 그 아역 왜 썼는지 모르겠다. 노래가 처량하게 들리지도 않았고 초반부터 거슬리던 말투 표정 발음.. 연출도 형편없었고 초반 마동석이 하드캐리....',
#   '1',
#   '171',
#   '21',
#   datetime.datetime(2016, 7, 22, 2, 52),
#   0],
#  ['dlqu****',
#   '박평식 돈받음?  다크나이트 평점 내릴때도 봤는데 정말 화남 영화도 억지감동과 스토리 아역배우,소희 연기 정말 구역질난다',
#   '1',
#   '225',
#   '82',
#   datetime.datetime(2016, 7, 20, 10, 42),
#   0],
#  ['가이(dlwj****)',
#   '평점보니 딱 알겠네... 언플만 열라 열심히하고 까보니 개발암 덩어리? 발연기와 발암 꼬맹이는 극의 집중을 방해한다는거 모르나?? 결국엔 이 영화도 배우빨 영화였군...',
#   '1',
#   '176',
#   '39',
#   datetime.datetime(2016, 7, 20, 12, 5),
#   0],
#  ['epun****',
#   '너무 허무해서 혹시모를까 영화 화면이 꺼질때 까지 앉아보았다...',
#   '7',
#   '183',
#   '50',
#   datetime.datetime(2016, 7, 20, 9, 13),
#   0],
#  ['hws6****',
#   '조기종영행 다시는 평식이 형 평점에 속지 않으리',
#   '1',
#   '253',
#   '120',
#   datetime.datetime(2016, 7, 20, 7, 22),
#   0],
#  ['kwan****',
#   '하....새로운시도는좋았다만 이건 뭐.. 10 no 잼',
#   '1',
#   '302',
#   '169',
#   datetime.datetime(2016, 7, 20, 10, 34),
#   0],
#  ['38da****',
#   '좀비가 너무 코믹행연기가 너무 어색행연출이 너무 단순행영화는 너무 부산행',
#   '4',
#   '275',
#   '143',
#   datetime.datetime(2016, 7, 20, 9, 16),
#   0],
#  ['아하(okma****)',
#   '9500이면 아프리카 많은 어린이들을 살릴 수 있습니다!',
#   '1',
#   '267',
#   '139',
#   datetime.datetime(2016, 7, 21, 20, 48),
#   '관람객'],
#  ['엘레깡스(pink****)',
#   '별로... 억지스러움 모두 다...',
#   '1',
#   '245',
#   '119',
#   datetime.datetime(2016, 7, 22, 2, 46),
#   '관람객'],
#  ['박성혁(psh0****)',
#   'ㅇㅅㅇ 기대보다 훨씬 많이 별로네요 재미없네요',
#   '1',
#   '235',
#   '112',
#   datetime.datetime(2016, 7, 20, 11, 37),
#   0],
#  ['빵떡순이(sook****)',
#   'KTX 객차간 문은 옆으로 슬쩍밀면 열리는데, 무슨 엄청 어렵게 여는 문처럼 나옴.. 좀비 수십명이 달려들어 실수로 쳐도 열리겠던데ㅋㅋㅋ',
#   '1',
#   '133',
#   '12',
#   datetime.datetime(2016, 7, 21, 11, 37),
#   0],
#  ['agmo****',
#   '일단 재미가없다. 개연성도없다. 연기를못하는 배우떄문에 몰입도도 떨어진다.',
#   '1',
#   '324',
#   '207',
#   datetime.datetime(2016, 7, 20, 10, 35),
#   '관람객'],
#  ['xhah****',
#   '한국형 좀비물 가능성 있네요. 좀비 좋아하시는 분들께추천합니다.',
#   '9',
#   '289',
#   '173',
#   datetime.datetime(2016, 7, 20, 11, 59),
#   '관람객'],
#  ['jsoa****',
#   '너무 영화가 부산스러워서 부산행일까 했음',
#   '1',
#   '147',
#   '33',
#   datetime.datetime(2016, 7, 20, 13, 34),
#   0],
#  ['몸짱(cpdu****)',
#   '하 ... 한국영화 명량 이후로 안보겟다고 다짐혹시나 해서 봣더니  역시나다   걍니들가서  봐라 나만 당하긴 억울하다',
#   '1',
#   '189',
#   '75',
#   datetime.datetime(2016, 7, 20, 11, 4),
#   0],
#  ['까만팬더(sl95****)',
#   '영화 스케일 대박이란 얘기를 듣고 가서 그런지 기대가 컸는데..좀비 바이러스가 어떻게 유출되었는지, 개연성도 없고어거지로 마무리한거같음 그리고인간이란게 얼마나 사악한지가 아니라 한국인이 얼마나 개악종인지를 보여준거...',
#   '1',
#   '147',
#   '35',
#   datetime.datetime(2016, 7, 20, 23, 13),
#   0],
#  ['레알(ahnp****)',
#   '돈과 시간이 매우 아깝다',
#   '1',
#   '165',
#   '53',
#   datetime.datetime(2016, 7, 20, 12, 32),
#   0],
#  ['kimj****',
#   '꼬마때문에 1점준다 애새끼가 존나 시끄러움 박애주의자 새끼',
#   '1',
#   '134',
#   '23',
#   datetime.datetime(2016, 7, 20, 22, 33),
#   0],
#  ['뿌꾸(lee6****)',
#   '3류 영화_ 좀비 영화의 수치네좀비 매니아로써 감독과 출연진들은 관람객들에게 다시한번 고개숙여 사과하라 - 워킹데드 보는게 더 실감나더라 - 어디 좀비 영화를 넘보냐~~',
#   '1',
#   '181',
#   '70',
#   datetime.datetime(2016, 7, 20, 10, 40),
#   0],
#  ['삼송갤럭시s7빵집(chld****)',
#   '평점은 서서히 올라갈 것이다. 큰 정치적 노선과 무난한 연출이 있으니 하지만 우리는 기억해야한다.연상호가 자본과 손잡았을때의 그 안일함을...그건 대놓고 신파보다ㅈ더 역겹다',
#   '1',
#   '192',
#   '81',
#   datetime.datetime(2016, 7, 20, 7, 58),
#   0],
#  ['꾸무딱(phm3****)',
#   '권혁수 닮은 할매가 이 영화 최고 악역이다. 감염자 무리들 뚫고 안전구역에 들어왔으면 격리조치 취하는건 당연한거지 지 언니 못들어왔다고 문 열어 재껴서 무고한 생존자들 죽인 살인자지 그게 ㅋㅋ 그걸 사이다니 뭐니 하...',
#   '1',
#   '168',
#   '58',
#   datetime.datetime(2016, 7, 21, 10, 23),
#   0],
#  ['천사(maya****)',
#   '돈 주고 보면 정말 아까운 영화. 이게 재밌다고 느끼면.. 좀비를 모르는 사람. 최소 10년전 나온 새벽의 저주 보면 너무 재미있어서 눈물 흘릴 듯.',
#   '1',
#   '167',
#   '61',
#   datetime.datetime(2016, 7, 20, 12, 18),
#   0],
#  ['션(seon****)',
#   '그래서 왜 좀비가 된거고 부산만 멀쩡한건데? 배경스토리부족..',
#   '1',
#   '119',
#   '16',
#   datetime.datetime(2016, 7, 22, 2, 28),
#   0],
#  ['said****',
#   '핵노잼 보는내내답답 몇몇발연기 엔딩...하....',
#   '1',
#   '195',
#   '96',
#   datetime.datetime(2016, 7, 21, 19, 22),
#   '관람객'],
#  ['kikitt(jjhh****)',
#   'ㅋ최악 흔한 여자아이 눈물로 감성팔이하고 부성애 모성애 연인들의 사랑 등등 아주 신파의 절정을 보여주네 공유뿐 아니라 배우들 연기는 극혐 몰입이 안됨.. 좀비들이  끌려가는씬에서는 고무보트에 타고 있는거 다보임  엉...',
#   '1',
#   '141',
#   '44',
#   datetime.datetime(2016, 7, 20, 11, 11),
#   0],
#  ['Atom(conf****)',
#   '여러 영화 짬뽕한거 같네요',
#   '5',
#   '196',
#   '101',
#   datetime.datetime(2016, 7, 20, 13, 14),
#   '관람객'],
#  ['Coredj(core****)',
#   '영화볼 돈으로 밥이나한끼 먹을껄...',
#   '1',
#   '136',
#   '42',
#   datetime.datetime(2016, 7, 20, 10, 53),
#   0],
#  ['귀신(nigh****)',
#   '별점5점 월드워Z  박평식 | 2013.06.17 떼거리 액션은 장관, 안일한 엔딩엔 허탈부산행 별점7점  박평식  2016.7.15쾌속의 감흥에서  신파의 터널로결론은 월드워Z보다  부산행이 더 잼있단얘기지?',
#   '1',
#   '146',
#   '52',
#   datetime.datetime(2016, 7, 20, 0, 49),
#   0],
#  ['반응(ckj1****)',
#   '심은경 특별출연인데 강한 인상남기고감 소희는 나만 어색한가???? 악역이 연기를 너무 잘해서 보는내내 화나는 영화',
#   '8',
#   '109',
#   '18',
#   datetime.datetime(2016, 7, 21, 2, 56),
#   '관람객'],
#  ['강한(khe2****)',
#   '무엇을 표현하고자 하는지 모르겠음.감동도 없고 여운도 없고 뭔가 남는게 하나도 없음.아 남는게 있다면..공유의 비현실적인 잘생김과 마동석의 하드케리와 정유미의 미모?극장서 영화 끝난후 모든관객들이 잠적..."...',
#   '1',
#   '175',
#   '86',
#   datetime.datetime(2016, 7, 21, 21, 26),
#   '관람객'],
#  ['빠샤빠샤(bsab****)',
#   '시도는 좋았으나 앞으로 더욱 발전할수있는 좀비물이 나올꺼라고 기대한다',
#   '1',
#   '121',
#   '33',
#   datetime.datetime(2016, 7, 20, 11, 41),
#   0],
#  ['sim(shim****)',
#   '승질나서 막판에 좀비될꺼같은영화',
#   '1',
#   '104',
#   '19',
#   datetime.datetime(2016, 7, 21, 1, 29),
#   0],
#  ['신화(thep****)',
#   '오늘개봉했다고 댓글이 너무 알바스럽네요                         판단은 당신의  몫',
#   '1',
#   '138',
#   '55',
#   datetime.datetime(2016, 7, 20, 1, 26),
#   0],
#  ['파란하늘(popo****)',
#   '살다살다 이딴 20년전 좀비영화 보다 못한 망작을 재난 블록버스터로 포장하고 ㅉㅉㅉ  영화 개떡같이 만들고 평점알바 언플 적당히 하면 떼돈번다는  국민을 개돼지로 보는 이런 잡영화는 망해야 한다 ㅉㅉㅉ 가족끼리 가서...',
#   '1',
#   '141',
#   '58',
#   datetime.datetime(2016, 7, 20, 1, 42),
#   0],
#  ['히아신스(vita****)',
#   '잼없음 재미없음 난 서율행',
#   '1',
#   '218',
#   '137',
#   datetime.datetime(2016, 7, 20, 21, 40),
#   '관람객'],
#  ['mode****',
#   '월드워z 많이 보고 배낀듯 마동석팔에 테이프감고 좀비 격투씬좀비들이 탑쌓고 쫒아오는씬초반에 볼거리는 많았으나 전반적으로 스토리가 끈어지는 느낌에 중반쯤 지루함을 떨칠수가 없었으며 막판의그 허무함...또 억지 감성유도...',
#   '1',
#   '108',
#   '28',
#   datetime.datetime(2016, 7, 20, 13, 10),
#   0],
#  ['산에들에(akfw****)',
#   '이렇게 한바탕 난리굿 떠는 소동영화들 다신 보지 말아야지~',
#   '1',
#   '147',
#   '67',
#   datetime.datetime(2016, 7, 20, 7, 13),
#   0],
#  ['로미(star****)',
#   '억지신파 전형적 옛날한국영화',
#   '2',
#   '156',
#   '77',
#   datetime.datetime(2016, 7, 20, 23, 59),
#   '관람객'],
#  ['jeri(gori****)',
#   '감정팔이는 그만 화끈한 좀비영화좀 만들어봐라..',
#   '1',
#   '173',
#   '94',
#   datetime.datetime(2016, 7, 20, 22, 4),
#   '관람객'],
#  ['popop(popo****)',
#   '장난하냐ㅋ 신파찍고 자빠졌네',
#   '1',
#   '118',
#   '40',
#   datetime.datetime(2016, 7, 20, 8, 17),
#   0],
#  ['양일(didd****)',
#   '괜히 봤다..  시작과 끝이 없는 영화, 즉 내용없는 영화다.. 마동석 제외하고는 연기들도 어색하고, 답없는 상업성만 강조한 삼류영화. 진짜 보지마세요 ㅋㅋ 인천상륙작전이 걱정되네요..',
#   '1',
#   '95',
#   '19',
#   datetime.datetime(2016, 7, 20, 23, 11),
#   0],
#  ['아낙(oss6****)',
#   '마동석형님때문에 재미는있으나 애기가 답답하고 짜증남 평소에는 문도 잘 닫더니 문 안닫아서 물리고 물리고 떠 물리고 어쩔땐 깨지는 문 어쩔땐 안깨지는 문',
#   '1',
#   '99',
#   '23',
#   datetime.datetime(2016, 7, 24, 15, 57),
#   '관람객'],
#  ['Pecolo(iam8****)',
#   '억지 스토리와 부자연스러운 cg 그리고 소희는 연기하지말자외국 좀비영화들 1%를 따라가지 못함',
#   '1',
#   '126',
#   '51',
#   datetime.datetime(2016, 7, 20, 10, 33),
#   0],
#  ['calw****',
#   '공유가 너~~무 답답함 그냥 영화 내내 멍때림좀비더미 효과는 월드워 Z 브랫핏나오는거 그대로 배끼고 주인공만 좀비변신 늦게함. 글고 펀드맨이 군인이랑 무슨인맥? 아색기는 너무 말 또박또박발음하고 말 더럽게 안들음 결...',
#   '1',
#   '95',
#   '21',
#   datetime.datetime(2016, 7, 20, 14, 25),
#   0],
#  ['sefx****',
#   '스토리가 없다..보면 후회합니다.',
#   '1',
#   '102',
#   '29',
#   datetime.datetime(2016, 7, 20, 12, 45),
#   0],
#  ['gkdl****',
#   '진심한개도주기아깝다 진심으로하는얘기인데 영화 집중은되고 재미? 솔직히 조금있는데 까놓고말해서 속답답하다 영화보는 내내 답답해서미칠지경이다 감독 영화만드느라수고했는데 너무관객들을 답답하게만들었다 상황이한두가지도아니고 ...',
#   '1',
#   '152',
#   '80',
#   datetime.datetime(2016, 7, 21, 1, 2),
#   '관람객'],
#  ['벨코라도(qkqk****)',
#   '그 아저씨 진짜 완전 아 짜증난다',
#   '10',
#   '84',
#   '14',
#   datetime.datetime(2016, 7, 22, 8, 15),
#   '관람객'],
#  ['사계절인간(dado****)',
#   '왜 좀비가 되었는지 제발 얘기해주면 안되나..치료법이나 해결하는 것이나와야지 그냥 하.. 기대한 내가잘못이지 내용좀 만들어서 영화좀 만들어요 제발..',
#   '1',
#   '72',
#   '3',
#   datetime.datetime(2016, 7, 23, 7, 32),
#   0],
#  ['오바김(dong****)',
#   '아역배우. 자매로 보이는 할머니 두명. 그리고 소희. 그외 대부분 배우들의 발연기는 내가 좀비가 되는 것 만큼이나 무섭고 어이가 없었다. 특히 좀비 분장할 돈 좀 아껴서 동생 할머니 분장 좀 신경쓰지. SNL 속 할...',
#   '1',
#   '75',
#   '6',
#   datetime.datetime(2016, 7, 21, 3, 40),
#   0],
#  ['윤도봉(yds9****)',
#   '영화속에서 환승이 안되서 답답했음',
#   '1',
#   '106',
#   '37',
#   datetime.datetime(2016, 7, 20, 1, 35),
#   0],
#  ['오월(yenn****)',
#   '이용철이가 8점 준 영화는 재미없다.안보러 가야 된다.',
#   '1',
#   '130',
#   '61',
#   datetime.datetime(2016, 7, 20, 10, 19),
#   0],
#  ['무(amug****)',
#   '우리나라 평론가들이 알바수준인이유가 뭘까? 정치적인넘들이기때문이지. -연에 얽혀 치맥 몇잔 얻어먹어가며 자기 사람인냥 챙기는 꼬라지.',
#   '1',
#   '102',
#   '34',
#   datetime.datetime(2016, 7, 20, 1, 43),
#   0],
#  ['오의(eoan****)',
#   '노잼..입니다. 낚이지 마세요',
#   '1',
#   '195',
#   '127',
#   datetime.datetime(2016, 7, 21, 22, 55),
#   '관람객'],
#  ['그라지마요박펠레(won9****)',
#   '이게 재밌어?? 양심적으로 이게 재밌어?? 나만 화나는거야?? 평론가들 양심에 손을 얹고 이게 7점짜리 영화야??? 내가 본 영화 중 쓰레기영화 탑 3안에 든다..이건 7광구 급인데??',
#   '1',
#   '89',
#   '22',
#   datetime.datetime(2016, 7, 20, 14, 17),
#   0],
#  ['송호준(who_****)',
#   '영화관에서 나가고 싶었음',
#   '1',
#   '150',
#   '84',
#   datetime.datetime(2016, 7, 21, 19, 2),
#   '관람객'],
#  ['깨비(sws0****)',
#   '아 진짜 재미없네요. 억지성 연출, 연기...보다 코믹인 줄 알았어요. 공유가 딸 태어났을 때 연출 말고는 전부 볼 게 없습니다. 다시는 보고싶지 않네요. 짜증만 남아요.',
#   '1',
#   '108',
#   '44',
#   datetime.datetime(2016, 7, 20, 11, 9),
#   0],
#  ['ㅁㄱ(hwan****)',
#   '8점대영화는아닌듯 그리고소희연기는 좀아니였음',
#   '1',
#   '76',
#   '15',
#   datetime.datetime(2016, 7, 20, 14, 40),
#   0],
#  ['미운오리(miun****)',
#   '우웩~~~  진짜 그닥이다',
#   '1',
#   '93',
#   '32',
#   datetime.datetime(2016, 7, 20, 10, 25),
#   0],
#  ['tmzk****',
#   '이걸 돈주고 봤다니...',
#   '1',
#   '129',
#   '68',
#   datetime.datetime(2016, 7, 21, 23, 15),
#   '관람객'],
#  ['블루(jhlo****)',
#   '보는내내  긴장하고  시간금방가고 좀비물매니아라  기대치에  영딸리지만  한국판좀비물이라 점수줌 별점 깎은건  배우연기들  특히  안소희 연기 오케이  한거에  어이가  없다',
#   '5',
#   '79',
#   '20',
#   datetime.datetime(2016, 7, 20, 9, 30),
#   0],
#  ['헤이즐넛(musa****)',
#   '기대이하네 ㅠㅠ  진심임',
#   '4',
#   '125',
#   '66',
#   datetime.datetime(2016, 7, 20, 7, 4),
#   0],
#  ['또케이티(flyi****)',
#   '별 하나도 아까운 b급 좀비 영화. 스토리 없음 그냥 좀비피해 도망다니다가 다 죽고 끝남',
#   '1',
#   '149',
#   '90',
#   datetime.datetime(2016, 7, 20, 22, 22),
#   '관람객'],
#  ['내친구 현대자동차(dken****)',
#   '징수3과 백성일 과장때문에 보러갑니다. 공유는 커피이후 나락으로',
#   '1',
#   '104',
#   '47',
#   datetime.datetime(2016, 7, 20, 1, 42),
#   0],
#  ['망고쥬스(rrla****)',
#   '끝나고 관객들이 웃었다  어이없는영화라서',
#   '1',
#   '68',
#   '12',
#   datetime.datetime(2016, 7, 20, 22, 28),
#   0],
#  ['서보현(qhgu****)',
#   '부(산행) 산으로 가는 영화',
#   '3',
#   '74',
#   '18',
#   datetime.datetime(2016, 7, 20, 8, 55),
#   0],
#  ['칼종(zkfw****)',
#   '할거없어도 보지말도록하자 믿어라',
#   '1',
#   '122',
#   '66',
#   datetime.datetime(2016, 7, 22, 8, 14),
#   '관람객'],
#  ['swso****',
#   '솔직히 마지막 공유 분유cf는 할말이 없다..',
#   '1',
#   '62',
#   '7',
#   datetime.datetime(2016, 7, 23, 7, 18),
#   0],
#  ['SED(dnam****)',
#   '억지 끼워맞추기식 감성팔이영화. 여자친구는 재밌게 봣다지만, 평소에 좀비물 조금이라도 봣던사람이면 진짜 재미없을듯.. 너무 비교되서. 이렇게 평이 좋을 수가 없는영화임. 알바쓴거같아..',
#   '1',
#   '69',
#   '16',
#   datetime.datetime(2016, 7, 20, 16, 10),
#   0],
#  ['춘배(c_lu****)',
#   '내용이 없을거면 재미라도 있던지. 보는 즐거움이라도 주던지. 슬퍼서 눈물이 나는 게 아니라 아쉬움에 눈물이 난다.ㅠㅠ',
#   '5',
#   '77',
#   '24',
#   datetime.datetime(2016, 7, 20, 10, 3),
#   0],
#  ['릭(myun****)',
#   '국제영화제에 이게 나갔다고요 ? 오바연기에.. 스토리는 그냥 나 좀비영화해보고싶어에..억지로 끼어맞춘 인간의 양면성.. 너무 부자연스러웠네요',
#   '1',
#   '63',
#   '12',
#   datetime.datetime(2016, 7, 20, 13, 31),
#   0],
#  ['화니(bimo****)',
#   '나만이상한건가 이게도대체 재및다는사람은뭔지 알바에존재를알게해준영화네 평점5점이적당',
#   '1',
#   '68',
#   '17',
#   datetime.datetime(2016, 7, 21, 10, 8),
#   0],
#  ['rhkd****',
#   '연상호 감독님의 애니를보고 많이 기대했습니다. 실망수준이 아닙니다. 그냥 치고받는 좀비액션영화',
#   '3',
#   '123',
#   '72',
#   datetime.datetime(2016, 7, 20, 12, 23),
#   '관람객'],
#  ['복순(dkak****)',
#   '국산 좀비는 아직인것 같다',
#   '1',
#   '125',
#   '74',
#   datetime.datetime(2016, 7, 20, 21, 6),
#   '관람객'],
#  ['다해(min_****)',
#   '너무기대했나봄 생각보단그저그랬음',
#   '7',
#   '194',
#   '143',
#   datetime.datetime(2016, 7, 20, 3, 7),
#   '관람객'],
#  ['정마으문(maam****)',
#   '연출 연기 총체적으로 쓰레기였고 신파 아니면 영화 못 마무리 지을거면 감독질은 때려치는게 좋을듯',
#   '1',
#   '54',
#   '4',
#   datetime.datetime(2016, 7, 21, 9, 8),
#   0],
#  ['Lorkan(bin8****)',
#   '좋은 배우 좋은 소재 좋은 연출력인데스토리가 전형적인 한국영화의 뻔함과 답답함에 중점을 둔건지캐릭터 스토리가 몽땅 사막에서 밤고구마 먹는 느낌악역한분빼고 주연분들 다 살고싶긴한건지 의문임',
#   '1',
#   '56',
#   '6',
#   datetime.datetime(2016, 7, 20, 12, 33),
#   0],
#  ['싱클레어(sinc****)',
#   '방금 보고 나온 평-인간의 이기심을 보여주려 했으나 방식이 서툴고 어색함. 안소희 좀비연기10점, 사람 연기0점. 어설픈CG. 스토리 빈약. 사람들이 어떻게 좀비가 되었는지에 대한 설명은 쿨하게 생략. 영화 중간에 ...',
#   '1',
#   '59',
#   '9',
#   datetime.datetime(2016, 7, 20, 14, 57),
#   0],
#  ['슬이짱(0103****)',
#   '핵노잼×1000 노잼',
#   '1',
#   '65',
#   '15',
#   datetime.datetime(2016, 7, 20, 16, 2),
#   0],
#  ['히응(rlaa****)',
#   '마지막 공유 좀비 되고 죽으려고 나오는 장면 보고 극장에서 아침부터 웃었다 ㅋㅋ 애니메이션이나 평상 만드세요',
#   '1',
#   '70',
#   '21',
#   datetime.datetime(2016, 7, 20, 11, 38),
#   0],
#  ['iWbwy(puer****)',
#   '구립니다. 진심입니다.',
#   '1',
#   '53',
#   '6',
#   datetime.datetime(2016, 7, 20, 22, 32),
#   0],
#  ['야옹(sktk****)',
#   '소희야....제발.... 연기 좀!! 화보찍고 그럴 시간에 연기 연습 좀 하세요.솔직히 나가고 싶었는데 정유미랑 공유가 괜찮아서 봤음.긴장감은 나쁘지 않았습니다. 그냥 킬링타임용 영화',
#   '5',
#   '58',
#   '11',
#   datetime.datetime(2016, 7, 20, 11, 36),
#   0],
#  ['MilkCoffee(godo****)',
#   '재미없음 진짜... 수위도 안높고 몰입도도없고',
#   '1',
#   '75',
#   '28',
#   datetime.datetime(2016, 7, 20, 11, 28),
#   0],
#  ['최지성(wltj****)',
#   '월드워z 한국판 킬링타임용임',
#   '1',
#   '91',
#   '44',
#   datetime.datetime(2016, 7, 20, 10, 36),
#   0],
#  ['주우운(kurt****)',
#   '최악의 똥을 삼킨 기분더럽다',
#   '1',
#   '96',
#   '50',
#   datetime.datetime(2016, 7, 25, 13, 44),
#   '관람객'],
#  ['Someoneelse(sw02****)',
#   '진짜 언플에 당했다. 원래 이런거 평점 안남기는데 너무 억울해서 남긴다.',
#   '1',
#   '50',
#   '5',
#   datetime.datetime(2016, 7, 22, 4, 1),
#   0],
#  ['KHM(hm42****)',
#   '인생의 2시간을 무가치하게 쓰기에 가장 좋은 방법',
#   '1',
#   '53',
#   '8',
#   datetime.datetime(2016, 7, 22, 3, 33),
#   0],
#  ['조영진(ohsh****)',
#   '이 배우들로 이딴거 밖에 못 만드니? 연출 누가했냐 개연성은 어디 소풍 보낸거야? 진짜  1점도 아깝다... 진짜 좀비영화인데 거짓말 안하고 마지막에 손가락 까딱하는거 그거에 딱 한번 놀랬다!! 이거 재밌다는애들은 ...',
#   '1',
#   '55',
#   '10',
#   datetime.datetime(2016, 7, 21, 10, 8),
#   0],
#  ['개간지훈남(what****)',
#   '알바들이 너무 많네...보고싶긴한데 보다 중간에 나올일이 생길까봐 보기가 두렵네... 좀비물이라... 왠지 유치할꺼같아...하....',
#   '1',
#   '77',
#   '32',
#   datetime.datetime(2016, 7, 20, 7, 40),
#   0],
#  ['병장님(jjl1****)',
#   '이 씨-발 진짜 어머니 모시고 갔는데 쌍욕하면서 나왔다 알로하 오에 나올때 소름돋았다ㅋㅋㅋㅋ 초반부터 후반까지 예상을 하나도 안빗나가고 할매는 무슨 소시오패시냐? 감독은 이딴씬 찍어놓고 드는 생각이 없냐? 후반은 신...',
#   '1',
#   '51',
#   '7',
#   datetime.datetime(2016, 7, 21, 1, 45),
#   0],
#  ['두더지(ssk9****)',
#   '알바들 많네.팩트없고 긴장감없고 재미없고 감동없고 개요없고 이유없고아무런 볼거리없는 영화.살다살다 이런영화는 또 첨이네....브레드 피트 나온 "월드워Z" 생각하고 보지마세요.',
#   '1',
#   '51',
#   '7',
#   datetime.datetime(2016, 7, 20, 15, 2),
#   0],
#  ['머쉬냥이(qnrj****)',
#   '좋다는 사람들은 어디서 오신분들인지..',
#   '1',
#   '178',
#   '134',
#   datetime.datetime(2016, 7, 21, 0, 11),
#   '관람객'],
#  ['minb****',
#   '월드워 z에서 이미 본 좀비들, 기차앞에선 좀비는 나오지 않는다. 뒤만 쫓을뿐. 좀비로 힘을 못받자 중간부터 아이의 눈물을 빌미로 풀어나가는 신파적 전개. 의상분장은 희미하고.. 칸이 이렇게 수준이 낮다니.. 마케팅...',
#   '1',
#   '56',
#   '13',
#   datetime.datetime(2016, 7, 20, 11, 19),
#   0],
#  ['지지(wlgu****)',
#   '구체적인 좀비 생성 과정이런것은 기대안함. 좀비 분장도 훌륭하고 연기도 탁월했습니다. 하지만 왜 굳이 어째서리 다된 좀비물에 한국 영화 특유의 후반부 억지 감동 팍팍 투입??',
#   '1',
#   '65',
#   '22',
#   datetime.datetime(2016, 7, 23, 13, 34),
#   '관람객'],
#  ['부농(psb4****)',
#   '월드워z보세요...ㅠ',
#   '1',
#   '107',
#   '64',
#   datetime.datetime(2016, 7, 20, 23, 46),
#   '관람객'],
#  ['비수(rhdq****)',
#   '마동석하드캐리입니다다닫',
#   '9',
#   '55',
#   '13',
#   datetime.datetime(2016, 7, 20, 18, 4),
#   '관람객'],
#  ['한재영(xxxo****)',
#   '단언컨데 최악입니다. 개연성 없는 에피소드와 대사,  공유와 유미? 마동석 씨를 제외한 오바스러운 연기는 절 화나게 만들었습니다',
#   '1',
#   '44',
#   '3',
#   datetime.datetime(2016, 7, 23, 6, 53),
#   0],
#  ['김진호(kjj4****)',
#   '노잼에 발암에 억지감동에 발연기에 뭐하나 부족한게 없네',
#   '1',
#   '46',
#   '5',
#   datetime.datetime(2016, 7, 20, 14, 24),
#   0],
#  ['으아니(akdl****)',
#   '감성팔이 더하기 등장인물들의 암유발하는 느릿느릿함 + 뒤통수 치기 특히 노숙자가 중간에 한 행동은 와... 응급실 실려갈 뻔 여기에 아저씨 토핑 추가 허무핰 결말 후에 남은건 짜증 뿐 또 바이러스가 왜 배포됬고 왜 ...',
#   '1',
#   '47',
#   '6',
#   datetime.datetime(2016, 7, 22, 0, 47),
#   0],
#  ['진준표(jp19****)',
#   '아이돌 그룹을 보는 것 같음. 마동석은 액션담당, 공유는 여자몰이와 감성팔이 담당 등등.... 좀비영화에 애매한 감성은 필요가 없음을 입증하고 있는 영화.',
#   '1',
#   '76',
#   '35',
#   datetime.datetime(2016, 7, 23, 14, 36),
#   '관람객'],
#  ['No min suk(sapo****)',
#   '외국좀비물에비해너무하네요',
#   '1',
#   '78',
#   '37',
#   datetime.datetime(2016, 7, 22, 1, 58),
#   '관람객'],
#  ['수달사순(pds8****)',
#   '애기 말 OO 안들어서 짜증남. 현실에서 좀비떼 나타나면 어른도 무서워서 오줌 지릴텐데 대전역에서 애색히 정의롭게 다른 사람 구하려들다가 아빠한테 하는 말"아빠는 자기만 알아서 이혼한거에요" 하더라. ...',
#   '1',
#   '42',
#   '2',
#   datetime.datetime(2016, 7, 25, 16, 49),
#   0],
#  ['퍼런이(egfd****)',
#   '역시 한국 좀비영화... 기대를 1도 저버리지않음.. 쓸데없이 오지랖만 많은 꼬맹이랑 문열렸는데 좀비랑 눈싸움하시는 할머니... 쓸데없는 감성팔이.. 한국좀비영화는 진짜 28주후나 월드워z같은 영화보고 좀 배웠으면 ...',
#   '1',
#   '45',
#   '5',
#   datetime.datetime(2016, 7, 21, 1, 29),
#   0],
#  ['yoqo(kako****)',
#   '전형적인 한국식 신파극.',
#   '1',
#   '48',
#   '8',
#   datetime.datetime(2016, 7, 20, 16, 3),
#   0],
#  ['나는양(dhtm****)',
#   '발암유발 핵노잼 ㅇㅇ 돈아까워 진짜',
#   '1',
#   '42',
#   '3',
#   datetime.datetime(2016, 7, 20, 12, 52),
#   0],
#  ['배성우(baes****)',
#   '좀비는 리얼했지만영화줄거리가 많이 아쉬웠다억지감동과 전개가 너무 느리다',
#   '1',
#   '44',
#   '5',
#   datetime.datetime(2016, 7, 20, 22, 31),
#   0],
#  ['qwpo****',
#   '정말 1점도 아깝다..배우들 연기를 보면 한숨이  나올정도다 안소희;;대체 누가 캐스팅한지;;그리고 한 상황에서 시간도 많이 끌고, 감정팔이를 하질 않나; 알바들 열심히 평 주느라 바쁘던데;차라리 월드워z 다운받아서...',
#   '1',
#   '46',
#   '7',
#   datetime.datetime(2016, 7, 22, 11, 53),
#   0],
#  ['리우(bran****)',
#   '역시 우리 마블리♥ 좀비 때려잡는데 박력이 장난아님',
#   '8',
#   '46',
#   '7',
#   datetime.datetime(2016, 7, 21, 8, 55),
#   '관람객'],
#  ['므(ncbe****)',
#   '스토리가 개연성도 부족하고 기대가 너무컸네요',
#   '6',
#   '63',
#   '24',
#   datetime.datetime(2016, 7, 20, 7, 32),
#   0],
#  ['Tompson(abtl****)',
#   '와 진심 돈아까운 영화 노잼 진짜 재미없어 평점 5 주고싶은데 평점 너무높아서 평균낼라고 1준다화가나서 쓴다올해 첫 천만 기대작이라고 영화소개프로에 나오던데 낚인 내가 한심하내 스토리 없는건 둘째치고 재미가 없다',
#   '1',
#   '42',
#   '4',
#   datetime.datetime(2016, 7, 21, 10, 14),
#   0],
#  ['sfim****',
#   '영화는 부산행 스토리는 안드로메다행',
#   '1',
#   '42',
#   '4',
#   datetime.datetime(2016, 7, 21, 10, 9),
#   0],
#  ['얍얍욥욥(curi****)',
#   '억지신파에 허술한전개와 갑갑한 캐릭터..생각보다 평점이 아직 높아서 1점드림',
#   '1',
#   '46',
#   '8',
#   datetime.datetime(2016, 7, 20, 12, 16),
#   0],
#  ['꼭지(jina****)',
#   '최악... 기대하고갔는데  노잼이네요',
#   '1',
#   '49',
#   '11',
#   datetime.datetime(2016, 7, 20, 12, 50),
#   0],
#  ['이수빈(qkfr****)',
#   '감명도 없고 결말도 없고 걍 슬프다...',
#   '3',
#   '60',
#   '22',
#   datetime.datetime(2016, 7, 20, 22, 30),
#   '관람객'],
#  ['kial****',
#   '내 생에 최악의 영화별점 1도 아깝다 소희의 웃픈연기는이지혜를 뛰어 넘었다',
#   '1',
#   '65',
#   '27',
#   datetime.datetime(2016, 7, 25, 11, 35),
#   '관람객'],
#  ['류변호사(solo****)',
#   '재미없음....',
#   '1',
#   '96',
#   '58',
#   datetime.datetime(2016, 7, 22, 2, 50),
#   '관람객'],
#  ['삽질추억(ppar****)',
#   '평식이 이색희 공포만좋아하네',
#   '1',
#   '42',
#   '5',
#   datetime.datetime(2016, 7, 20, 12, 3),
#   0],
#  ['robi****',
#   '스토리 개연성 사운드 분장 뭐 하나뛰어난점 없다 13년전  만든 28일후를  비교해서  하는말이다. 미대전공자로써 조금  실력있는친구들과 일주일이면 똑같은 형태로만들수있을꺼라 자신한다. 보지마라  돈아깝다.   댓글...',
#   '1',
#   '43',
#   '6',
#   datetime.datetime(2016, 7, 20, 18, 2),
#   0],
#  ['혈뢰(1004****)',
#   '실망 이단어로 모든게설명된다.',
#   '1',
#   '43',
#   '6',
#   datetime.datetime(2016, 7, 20, 13, 3),
#   0],
#  ['판사(into****)',
#   '워킹데드게임, 새벽의저주, 설국열차, 기타 잡스런 재난 영화의 플룻이란 플룻은 다 덕지 덕지 발라 놓은 영화. 뭐하나 제대로 마무리 하는것 하나 없이 결말은 언제나 하는 것 없이 소리만 질러대는 쓸모없는 사람들만 생...',
#   '1',
#   '45',
#   '8',
#   datetime.datetime(2016, 7, 20, 14, 26),
#   0],
#  ['서영(sun0****)',
#   '평점 써본적도 없는데 찾아 들어와서 씁니다.... 살면서 본 영화중 가장 최악... 억지감동과 진부한 전개의 향연. 발연기는 보너스.',
#   '1',
#   '43',
#   '7',
#   datetime.datetime(2016, 7, 21, 2, 43),
#   0],
#  ['알타리(alta****)',
#   '억지신파, 개연성 낮음, 주연배우들의 악연.... 마동석을 앞세운 광고효과로 반짝 뜨는 영화.. 게다가 연기의 대부분이 어설픈 애드립 같은 마동석.. 대본을 누가 썼는지 정말 아쉽다.',
#   '1',
#   '44',
#   '8',
#   datetime.datetime(2016, 7, 22, 13, 32),
#   0],
#  ['고쟁이(ipki****)',
#   '최근 본 영화중 가장 이상했던 영화',
#   '1',
#   '67',
#   '31',
#   datetime.datetime(2016, 7, 23, 16, 14),
#   '관람객'],
#  ['리나맘마(rain****)',
#   '올해 본 영화중에서 역대급 최악이었어요 개연성도 없고 어디서부터 바이러스가 시작된건지에대한 내용은 1도없고크으아아악 이렇게 시작해서 크으아아악 이렇게 끝나는영화에요 최악입니다',
#   '1',
#   '77',
#   '41',
#   datetime.datetime(2016, 7, 21, 23, 50),
#   '관람객'],
#  ['모찌(park****)',
#   '내인생최악의영화예요',
#   '1',
#   '87',
#   '51',
#   datetime.datetime(2016, 7, 25, 16, 31),
#   '관람객'],
#  ['힘(dahi****)',
#   '댓글알바오지네 너무했다...진짜..',
#   '1',
#   '48',
#   '13',
#   datetime.datetime(2016, 7, 21, 2, 58),
#   0],
#  ['gusr****',
#   '영화평점 처음쓰는데 ...보는데  암걸이겠다 스토리도짜증 연기도 짜증 좀비하고 술래잡기하는것도아이고 .. 참내 ...',
#   '1',
#   '51',
#   '16',
#   datetime.datetime(2016, 7, 23, 19, 52),
#   '관람객'],
#  ['Parkstar(zxzx****)',
#   '너무 상업적으로 접근하고있다 연상호감독의 특징이 돋보이지 않아 실망했다. 돼지의왕.사이비 너무 재밌게봐서그런가..',
#   '5',
#   '63',
#   '28',
#   datetime.datetime(2016, 7, 20, 6, 56),
#   0],
#  ['pret****',
#   '그냥 그닥.. 너무 눈물짜내려고하는듯..',
#   '4',
#   '67',
#   '32',
#   datetime.datetime(2016, 7, 20, 22, 12),
#   '관람객'],
#  ['칼리아(lupe****)',
#   '별로... 취향에안맞아서그런지..',
#   '1',
#   '71',
#   '36',
#   datetime.datetime(2016, 7, 21, 17, 11),
#   '관람객'],
#  ['박성우(park****)',
#   '대한민국 좀비 영화 수준.. 최악이네.. 어설픈 스토리 긴장감 없고.. 핵 노잼',
#   '1',
#   '45',
#   '11',
#   datetime.datetime(2016, 7, 20, 22, 34),
#   0],
#  ['ansa****',
#   '뭔가 부족한느낌 그냥그럼',
#   '3',
#   '66',
#   '32',
#   datetime.datetime(2016, 7, 21, 0, 54),
#   '관람객'],
#  ['pang****',
#   '연상호씨는그냥그림그립시다',
#   '1',
#   '36',
#   '3',
#   datetime.datetime(2016, 7, 21, 10, 12),
#   0],
#  ['꼬꼬마(009h****)',
#   '재난영화 뻔함을 좀비가 메꿔주려나 햇는데 이건뭐 단세포 수준 반복되는 습격 되려 지겨움 헛웃음만ㅉㅉ',
#   '1',
#   '36',
#   '3',
#   datetime.datetime(2016, 7, 21, 9, 48),
#   0],
#  ['전지현될뻔(rud3****)',
#   '뻔하고재미없어 차라리REC다시보기가더재미있을듯',
#   '1',
#   '49',
#   '16',
#   datetime.datetime(2016, 7, 20, 10, 16),
#   0],
#  ['와우와우(saem****)',
#   '마동석이 다살려놓고 다시 죽어가는 영화기대가 커서 그런지 그닥 그러네요',
#   '5',
#   '54',
#   '21',
#   datetime.datetime(2016, 7, 20, 10, 53),
#   0],
#  ['zena****',
#   '믄데 끼아아아악악악꾸에에엑엑엑',
#   '1',
#   '67',
#   '34',
#   datetime.datetime(2016, 7, 21, 3, 6),
#   '관람객'],
#  ['범고래(dkfh****)',
#   '다세포소녀보다 났고 태왕사신기보다 못한 cg와 스토리?',
#   '1',
#   '74',
#   '41',
#   datetime.datetime(2016, 7, 20, 9, 49),
#   0],
#  ['hbbo****',
#   '0점!보는 내내 괴롭고 나가고 싶던 영화비추!!!시사회때 제작진들과 배우들이 무슨 마음으로 봤을지 궁금하더라',
#   '1',
#   '34',
#   '2',
#   datetime.datetime(2016, 7, 21, 22, 47),
#   0],
#  ['nobis(fhdn****)',
#   '마동석아저씨의 멋진 액션씬. 근데 좀비감염이 일관성이 없음.엑스트라들과 주인공 및 몇몇 조연들의 감염시간차이 심함. 그리고 임신하신 여배우분은 아기 가진거치고 너무 잘달리고 너무 꼿꼿하심. 전반적으로 의문스러웠던영화...',
#   '1',
#   '36',
#   '4',
#   datetime.datetime(2016, 7, 20, 16, 43),
#   0],
#  ['쓰루(chy0****)',
#   '아오..38사기동대 징수3과 백성일 과장 마동성행님이 너무 아깝다 ㅜ',
#   '1',
#   '55',
#   '23',
#   datetime.datetime(2016, 7, 20, 4, 25),
#   0],
#  ['xayo****',
#   '홍보가과한듯합니다 몰입도가죽여준다더니 ㅋㅋㅋ 몰입도안되고...좀비영화아직은아닌가봅니다',
#   '1',
#   '80',
#   '48',
#   datetime.datetime(2016, 7, 21, 0, 48),
#   '관람객'],
#  ['공군무장(dakg****)',
#   '기대가 너무 컷나보네요.. 재밋긴한데..',
#   '1',
#   '33',
#   '2',
#   datetime.datetime(2016, 7, 20, 12, 0),
#   0],
#  ['guja****',
#   '이영화의 문제점  1. 배경음악(80년대 심형래영환줄 개유치..) 2.안소희연기(내가더낫겠다..) 3. 이해안가는스토리..(할머니 살수있는데 웃으며 자살선택.. 공유 모유수유 연기... 등등...) 4. 긴장감하나도...',
#   '1',
#   '36',
#   '5',
#   datetime.datetime(2016, 7, 24, 23, 54),
#   0],
#  ['준석이(jnus****)',
#   '원래 좀비물 좋아하던 사람들에게는 득,      개연성을 고려하는 사람들에게는 실',
#   '1',
#   '39',
#   '8',
#   datetime.datetime(2016, 7, 21, 10, 38),
#   0],
#  ['정든인생(fks6****)',
#   '공유가애기처럼 우는데도 잘생겼더라ㅠ',
#   '10',
#   '44',
#   '13',
#   datetime.datetime(2016, 7, 21, 19, 27),
#   '관람객'],
#  ['달려비야(tlsg****)',
#   '내평점 안소희가 말아먹고 내용은 중구 남방인 B급 영화. 이걸 집에서봤으면 단언하건데 분명히 껐다. 친구가 하도 재미있다 우겨서 봤는데  돈아깝다.',
#   '1',
#   '33',
#   '3',
#   datetime.datetime(2016, 7, 21, 10, 24),
#   0],
#  ['libe****',
#   '뜯어 먹고 열차객실 문 닫는 장면밖에 없네요...좀비출현 원인과 소탕방법도 없고...잔인한 실망',
#   '1',
#   '45',
#   '15',
#   datetime.datetime(2016, 7, 25, 7, 16),
#   '관람객'],
#  ['하하호호임(such****)',
#   '군인들 산더미처럼 쏟아졌을 때 밟히는 군인 "인형"들 너무 티났고, 공유랑 전혀 안 닮은 못생기고 의미없는 딸내미, 연기하는 게 너무 티나는 무명 발암 배우, 왜 캐스팅 됐는지 의문인 발연기 소희, 좀...',
#   '1',
#   '31',
#   '2',
#   datetime.datetime(2016, 7, 25, 17, 17),
#   0],
#  ['aurevoir(merc****)',
#   '마니 아쉽다. cg 를 비롯해 연기. 연출 모든게 어정쩡한 영화. 평론가와 난 보는 눈이 다른 듯',
#   '2',
#   '31',
#   '2',
#   datetime.datetime(2016, 7, 20, 10, 58),
#   0],
#  ['비의몸매(zoom****)',
#   '20대여자를 할머니 분장시켜놓고 할매연기시킴. 박지선이냐,',
#   '1',
#   '28',
#   '0',
#   datetime.datetime(2016, 7, 24, 19, 55),
#   0],
#  ['melo****',
#   '영화에 비해 평점이 너무 높다',
#   '1',
#   '33',
#   '5',
#   datetime.datetime(2016, 7, 20, 23, 1),
#   0],
#  ['운디네(swam****)',
#   '연상호 감독님. 창피하지 않습니까? 당신이 영화에서 그렸던 부조리.. 당신이 실천하고 있네요. 변칙개봉에 상영관 삼키기에.. 어쩌다 그리되셨나요.',
#   '1',
#   '33',
#   '5',
#   datetime.datetime(2016, 7, 20, 12, 37),
#   0],
#  ['junc****',
#   '정말답도없는영화다 유치찬란과 감성팔이의끝',
#   '1',
#   '35',
#   '7',
#   datetime.datetime(2016, 7, 22, 3, 52),
#   0],
#  ['rlat****',
#   '28일후, REC, 레지던트이블 등등등 좀비영화 좋아하시는 분은 부산행보면 저 처럼 평점 1점 남깁니다.. 한마디로 억지감동 개연성 ㄴ 분명 슬픈장면인데 웃음유발..',
#   '1',
#   '35',
#   '7',
#   datetime.datetime(2016, 7, 21, 10, 23),
#   0],
#  ['none(bih3****)',
#   '답답해 돌아버리는 영화 내용도 없고 좀비가 어떻게 나왔는지는 설명도안해주고 마지막엔 억지감동만 끼워넣음...사이다없이 고구마 백개 쳐먹은 기분',
#   '1',
#   '35',
#   '7',
#   datetime.datetime(2016, 7, 20, 21, 29),
#   0],
#  ['정보(gmlw****)',
#   '내가 이 영화 천만에 기여했다니...극 중 다급한 사람은 아무도 없다. 굳이 안들어가도 되는게 너무너무 많아서 영화가 산으로 간다.다른 사람들이 놀라고 눈물 흘릴때 그냥 미간만 찌푸려졌다.',
#   '1',
#   '39',
#   '11',
#   datetime.datetime(2016, 8, 6, 21, 0),
#   '관람객'],
#  ['다비(kang****)',
#   '기차라는 소재 신의한수 ㄷㄷ긴장감 최고',
#   '9',
#   '44',
#   '16',
#   datetime.datetime(2016, 7, 22, 21, 31),
#   '관람객'],
#  ['hee2****',
#   '내인생 최고의 쓰레기영화',
#   '1',
#   '66',
#   '38',
#   datetime.datetime(2016, 7, 23, 2, 8),
#   '관람객'],
#  ['EUN(hear****)',
#   '재밌다고해서 봤는데 전 내내 지루했어요. 처음에 너무 지루해서 나갈까 했는데 시작한지 겨우 30분정도-  그냥 좀비설명영화 같았어요. 좀비는 이런 특징이 있다 - 하고 설명해주는. 아무튼 별로였습니다',
#   '1',
#   '82',
#   '54',
#   datetime.datetime(2016, 7, 21, 22, 56),
#   '관람객'],
#  ['alst****',
#   '해영씨  스카프 스카프 돌아갔어',
#   '1',
#   '27',
#   '0',
#   datetime.datetime(2016, 7, 22, 1, 47),
#   0],
#  ['raxe****',
#   '여자아인줄 모르고 남자애가 요새 아이답지 않게 효자구나 싶었다 근데 갑자기 차마입고 나와서 무서웠다 더운날 사람 울게 만들려고 노력은 했으나 신파가 극에 치달아 울화통이 터졌고 아이의 노래에서 이미 난 열반의 경지에...',
#   '1',
#   '28',
#   '1',
#   datetime.datetime(2016, 7, 24, 20, 16),
#   0],
#  ['dlgk****',
#   '인터스텔라, 다크나이트 같은 영화 재밌게 보신 분들은 절대 재미 없을 영화입니다. 영화가 상당히 많이 억지스러워요.',
#   '1',
#   '30',
#   '3',
#   datetime.datetime(2016, 7, 20, 22, 39),
#   0],
#  ['쿨하마(true****)',
#   '기승전결도 없고 반전도 복선도 감동도 아무것도 없는 영화',
#   '1',
#   '31',
#   '4',
#   datetime.datetime(2016, 7, 21, 11, 24),
#   0],
#  ['vict****',
#   '안소희 발연기 본인은 모르나???알아서 나오지 말아야지...이름 좀 있다고 그냥 캐스팅 막하지 맙시다!!!알바와의 균형을 맞추기 위해 1!',
#   '1',
#   '32',
#   '5',
#   datetime.datetime(2016, 7, 22, 13, 42),
#   0],
#  ['주노님(juno****)',
#   '보다가 하품나서 눈물 닦는데 옆에 아줌마 흐느끼는거 보고 더 놀램',
#   '1',
#   '32',
#   '5',
#   datetime.datetime(2016, 7, 20, 13, 2),
#   0],
#  ['seoul997(1x10****)',
#   '보는 내내 짜증. 싸구려 감동이나 자아냄. 외국 영화 짜깁기. 후반 기차에 좀비 달고가는 씬에는 마네킹다리 다 보임. 내 돈주고 보기 아까운 영화. 결말도 <미스트>처럼 공허하면 나은데 이건 엔딩크레딧에 ...',
#   '1',
#   '50',
#   '23',
#   datetime.datetime(2016, 7, 26, 9, 28),
#   '관람객'],
#  ['kjs1****',
#   '영화 구성이 엉망입니다',
#   '1',
#   '55',
#   '28',
#   datetime.datetime(2016, 7, 23, 15, 11),
#   '관람객'],
#  ['whytheface01(ktw1****)',
#   '이걸 돈주고 보다니..',
#   '1',
#   '29',
#   '3',
#   datetime.datetime(2016, 7, 22, 0, 57),
#   0],
#  ['성영(kng0****)',
#   '재밌다는거 다 낚으려는 속셈입니다 혹시나 보는 붕글 마동석죽으면 나오세요',
#   '1',
#   '29',
#   '3',
#   datetime.datetime(2016, 7, 21, 12, 18),
#   0],
#  ['사과(b4ra****)',
#   '피칠갑 좀비. 문열고 문닫고 문열고 문닫고',
#   '1',
#   '29',
#   '3',
#   datetime.datetime(2016, 7, 20, 22, 22),
#   0],
#  ['do42****',
#   '아... 정말 재미없다.',
#   '1',
#   '30',
#   '4',
#   datetime.datetime(2016, 7, 22, 0, 6),
#   0],
#  ['iamkyung(daky****)',
#   '호불호가 크게 갈리길래 기대는 안했지만...총체적 난국....',
#   '1',
#   '32',
#   '6',
#   datetime.datetime(2016, 7, 22, 5, 48),
#   0],
#  ['insa****',
#   '좀비도 사람도 안무섭습니다. 네이버 평점이 무섭습니다.',
#   '1',
#   '37',
#   '11',
#   datetime.datetime(2016, 7, 28, 12, 45),
#   '관람객'],
#  ['장인철(icja****)',
#   '내용이너무빈약한듯 합니다.',
#   '1',
#   '39',
#   '13',
#   datetime.datetime(2016, 7, 24, 0, 34),
#   '관람객'],
#  ['호랭이(goxo****)',
#   '여기서 재밋다고 하는것들은 댓글알바나 뇌가없는것들이다',
#   '1',
#   '43',
#   '17',
#   datetime.datetime(2016, 7, 20, 12, 46),
#   0],
#  ['jjjjjun(vsan****)',
#   '한국영화 진짜 못만드네 역시',
#   '1',
#   '27',
#   '2',
#   datetime.datetime(2016, 7, 21, 21, 52),
#   0],
#  ['dondon(dive****)',
#   '나만 당할 순 없지. 하고 남들에게 보게하지마라..  너무 아니다 이건',
#   '1',
#   '29',
#   '4',
#   datetime.datetime(2016, 7, 22, 16, 33),
#   0],
#  ['플립(ramg****)',
#   '올해 최악의 영화 중에 하나였다 일단 배경이나 분위기도 다른 좀비 영화에 비해서 너무 밝았고삽입곡도 엉망이었다그리고  중후반에 감성팔이는 관객을 모으려고 그랬는지 모르겠지만 오히려 짜증만 났다평론가 박평식이 왜 이 ...',
#   '1',
#   '29',
#   '4',
#   datetime.datetime(2016, 7, 20, 23, 24),
#   0],
#  ['kimh****',
#   '그닥 별루 답답한 영화였음',
#   '1',
#   '38',
#   '13',
#   datetime.datetime(2016, 7, 24, 0, 32),
#   '관람객'],
#  ['mush****',
#   '동양좀비 웃길 줄 알았는데 진짜 소름끼쳤고 잘만들었다. 계속 깜짝깜짝 놀라서 심장 내려앉을뻔...ㅠ',
#   '10',
#   '40',
#   '15',
#   datetime.datetime(2016, 7, 21, 22, 50),
#   '관람객'],
#  ['mape****',
#   '한국 최초 좀비영화에 박평식이 7점 줬다해서 보러갔는데 아주 가관이여....',
#   '1',
#   '47',
#   '22',
#   datetime.datetime(2016, 7, 24, 2, 57),
#   '관람객'],
#  ['채영(scy4****)',
#   '공유.. 넘 멋져요 좋아요',
#   '10',
#   '25',
#   '1',
#   datetime.datetime(2018, 1, 12, 16, 52),
#   '관람객'],
#  ['아기쪽쪽(goqk****)',
#   '스토리 너무 질질 끌고 할머니도 들어올수 있는데 그 열차칸까지 잘 오다가 문 앞에서 가만히 서있어서 죽는것도 어이없고조연 주연급들은 아름다운 좀비 변신으로 몇분 동안 버티고일반 좀비들은 바로바로 변하는 것도 어이없음...',
#   '1',
#   '26',
#   '2',
#   datetime.datetime(2016, 7, 28, 2, 6),
#   0],
#  ['수탉(sch_****)',
#   '3줄요약. 1. ㅅㅎ연기로 영화 반이상망침. 2. 몇년이지나도 발전없는 한국영화cg개극혐. 3. 깨알같던 배재대학교 홍보 극혐',
#   '1',
#   '27',
#   '3',
#   datetime.datetime(2016, 7, 21, 7, 38),
#   0],
#  ['권승아(dhks****)',
#   '외국좀비영화와 견주어봐도 손색없을 정도로 좀비에 대해서는잘표현한것같아요! 근데 스토리는 한국영화에서 흔히볼수있는 스토리라 많이 진부하고 뻔한감성유발같았어요ㅠㅠ',
#   '5',
#   '32',
#   '8',
#   datetime.datetime(2016, 7, 22, 7, 22),
#   '관람객'],
#  ['gsdaggagasdcx(ehsd****)',
#   '한국애서 만들었다는거 감안하면 평점 7점대가 딱 적당하다. 외국에서 이렇게 신파 남발하면서 좀비영화만들었다간 평점 4점대넘기힘들거다.',
#   '1',
#   '24',
#   '1',
#   datetime.datetime(2016, 7, 22, 1, 1),
#   0],
#  ['레디오(puln****)',
#   'ㅅㅂ 평점알바도 적당히써야지어째 이런 ㅅㄹㄱ영화도 8점이 넘을수가있냐아님 한국관객 수준이 ㅅㄹㄱ 인 때문인지도 모르겠다마는..ㅉㅉ',
#   '1',
#   '24',
#   '1',
#   datetime.datetime(2016, 7, 22, 0, 57),
#   0],
#  ['네버랜드(wpxm****)',
#   '난 제일 어이없던게.. 주연들이 하나 같이 바보같다라는거다.마동석 좀비될때도 머리앞에 손을 갖다주지않나..소희 좀비 될때도 좀비가 올걸 알면서 왜 뒷문은 안닫았나 싶고.공유 좀비될때도 왜 굳이 입에다가 손을 대주나 ...',
#   '1',
#   '26',
#   '3',
#   datetime.datetime(2016, 7, 25, 17, 6),
#   0],
#  ['팬더 찬(mini****)',
#   '중간중간 나오는 감성팔이에 흐름뚝뚝 끊기고 긴장감 다 놓침. 멀뚱대는거 3초씩만 짤라라. 소희는 연기도 못하는데 생긴것도 이상하고. 아역은 암유발 차라리 지병있는게 낫지 징징대는건 못봐주겠네 마동석이 주인공인줄.나중...',
#   '1',
#   '28',
#   '5',
#   datetime.datetime(2016, 7, 22, 15, 56),
#   0],
#  ['라마캉(wkdu****)',
#   '화장실을 돈을 내고 가고 싶다면 보세요',
#   '1',
#   '28',
#   '5',
#   datetime.datetime(2016, 7, 22, 13, 28),
#   0],
#  ['51kjt(west****)',
#   '마동석없으면 이건뭐 재미진짜없더라',
#   '2',
#   '29',
#   '6',
#   datetime.datetime(2016, 7, 20, 11, 20),
#   0],
#  ['아뉴(dlgl****)',
#   '공유 수트핏에 일점. 나머지는 한국식 신파 중에서도 가장 급 낮은 신파 구조.... 실소를 많이 하게 되는 영화',
#   '1',
#   '35',
#   '12',
#   datetime.datetime(2016, 7, 25, 23, 32),
#   '관람객'],
#  ['sns2****',
#   'ㅜㅜ재미없네요ㅜㅜ넘 재미없네요ㅜㅜ',
#   '1',
#   '40',
#   '17',
#   datetime.datetime(2016, 7, 20, 10, 59),
#   0],
#  ['개세포소(dnfk****)',
#   '진짜 월드워z 따라만드느나 수고했다 기왕이면 좀비탑도 만들지 그랬냐',
#   '1',
#   '41',
#   '18',
#   datetime.datetime(2016, 7, 22, 23, 48),
#   '관람객'],
#  ['천동민(cjse****)',
#   '핵노잼 진심 왜 이딴식으로 영화를 만드는지 모르겠음',
#   '1',
#   '47',
#   '24',
#   datetime.datetime(2016, 7, 22, 16, 23),
#   '관람객'],
#  ['정원우(jeon****)',
#   '작년에 개봉한 외국 좀비영화보다 낫다 좀비 나오는 영화가 쫓고 쫒기고 하다가 끝나는것 큰 기대는 하지 말길 바랍니다',
#   '7',
#   '66',
#   '43',
#   datetime.datetime(2016, 7, 20, 10, 58),
#   '관람객'],
#  ['유현군(cuhy****)',
#   "'한국영화인데 이 정도라고??' 라고 보기시작했다가 '에라이 누가 한국영화 아니랄까봐 어휴~' 로 끝나는 영화 좋게 포장해서 이 정도로 표현한거지 보는동안 혼자 속으로 계속 욕하게 되더라...",
#   '1',
#   '24',
#   '2',
#   datetime.datetime(2016, 7, 23, 15, 33),
#   0],
#  ['im00****',
#   '상영내내 어이없는웃음만 나왔는데 재밌다고 하는사람은 뭐지?공유같이 연기잘하는배우도 연기 못해보이게 나오게 만든 연출력 대박이던데..마케팅의힘인가? 앞뒤설명 제대로 안나오고 이해안되는건 나와 내일행뿐들이었던가? 정말 ...',
#   '1',
#   '25',
#   '3',
#   datetime.datetime(2016, 7, 25, 15, 4),
#   0],
#  ['걸죽이(rsm_****)',
#   '정의실현  너무 했다 정말 ..',
#   '1',
#   '25',
#   '3',
#   datetime.datetime(2016, 7, 22, 6, 42),
#   0],
#  ['임팩트(sms_****)',
#   '안소희 연기 지적하는 글이 1위였는데 내려갔네.. 또 알바 풀었냐..',
#   '1',
#   '26',
#   '4',
#   datetime.datetime(2016, 7, 21, 9, 5),
#   0],
#  ['tmfeoddl(tmfe****)',
#   '평점이 너무높음. 기대하지마시고 암유발자들몇명나옴 일단안소희 개발연기로 영화몰입방해 . 아역 역할이랑 안어울림 특히 마지막노래씬은 최악.. 연기좀 늘러야할듯',
#   '1',
#   '27',
#   '5',
#   datetime.datetime(2016, 7, 28, 0, 8),
#   0],
#  ['Hooneykoon(namh****)',
#   '솔직히 1점도아깝다..정말 한평생본영화중 최악이다..스토리도없고..무슨생각으로 영화를만든건지ㅡ.ㅡ 방역쪼금 머가 유출됬대요. 이게끝? 감염된여자하나 열차타고. 우르르감염되다가 나중에 좀비보고싶으면 질리도록나오니 강추...',
#   '1',
#   '27',
#   '5',
#   datetime.datetime(2016, 7, 20, 22, 11),
#   0],
#  ['보거스(gmh2****)',
#   '나만 볼수없지 ㅋㅋㅋㅡㅡ',
#   '1',
#   '31',
#   '9',
#   datetime.datetime(2016, 7, 25, 1, 3),
#   '관람객'],
#  ['andm****',
#   '칵!!!카악 캌!!!',
#   '1',
#   '36',
#   '14',
#   datetime.datetime(2016, 7, 24, 18, 54),
#   '관람객'],
#  ['대박이(dhsf****)',
#   '아무리 영화라지만 좀비들이 기차 물고늘어지는 장면은  너무아니드라 ㅡㅡ',
#   '1',
#   '37',
#   '15',
#   datetime.datetime(2016, 7, 22, 10, 1),
#   '관람객'],
#  ['eocn****',
#   '개연성이 부족하고 원인을 몰라 아쉽다',
#   '6',
#   '43',
#   '21',
#   datetime.datetime(2016, 7, 20, 21, 32),
#   '관람객'],
#  ['함아함아(s777****)',
#   '초반에는 좀비가 나중에는 사람이 무서웠던 영화ㅎ 진짜 재미있었어요!!',
#   '10',
#   '44',
#   '22',
#   datetime.datetime(2016, 7, 20, 19, 12),
#   '관람객'],
#  ['투명망토(euij****)',
#   '현실적인 프레임에 호러 개그 액션 감동을 토핑한 스토리. 그러나 우발적인 행동들에 대해서는 마냥 공감할 수는 없는 영화.',
#   '10',
#   '61',
#   '39',
#   datetime.datetime(2016, 7, 20, 17, 34),
#   '관람객'],
#  ['코키(pigk****)',
#   '월드워Z 많이 따라한게 보인다.이영화 평점이 월드워Z보다 높다니,,, 알바 적당히 풉시다',
#   '1',
#   '23',
#   '2',
#   datetime.datetime(2016, 7, 23, 15, 34),
#   0],
#  ['rfg(hoha****)',
#   '우리나라에도 좀비영화가 가능하다는것을 잘보여준 작품',
#   '10',
#   '24',
#   '3',
#   datetime.datetime(2018, 7, 17, 12, 3),
#   '관람객'],
#  ['broo****',
#   '눈오는 날에 기차타고 가다가 감기걸리는 삼류영화',
#   '1',
#   '27',
#   '6',
#   datetime.datetime(2016, 7, 20, 12, 27),
#   0],
#  ['우는갈매기(skm3****)',
#   '좀 유치한다....!',
#   '1',
#   '28',
#   '7',
#   datetime.datetime(2016, 7, 20, 12, 54),
#   0],
#  ['프로필(ki38****)',
#   '코로나 사태 보면서 김의성의 재평가가 시급하다... 김의성 말대로 했으면 훨씬 많이 살았다... 진즉에 중국 막았어야...',
#   '10',
#   '21',
#   '1',
#   datetime.datetime(2020, 2, 25, 12, 12),
#   0],
#  ['꿍꽝꽁(gero****)',
#   '내생에 첫 평점. 개연성제로 그냥 좀비다! 다죽어감 흑흑 개슬픔 그러나 살아남음 흑흑 슬픔 흑흑',
#   '1',
#   '22',
#   '2',
#   datetime.datetime(2016, 7, 21, 9, 54),
#   0],
#  ['PRIDE(esle****)',
#   '평론가들 매수하는 클라스가 대단하네요 워킹데드나 보세요',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2016, 7, 25, 15, 14),
#   0],
#  ['차차돌(cho7****)',
#   '영화관 가면 부산행만 상영하니 어쩔수 없이 보게된다. 최악',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2016, 7, 25, 15, 11),
#   0],
#  ['jeon****',
#   '내가시바 네이버평점 첨단다.. 걍 OOO기야 보지말자 평점 알바쓴듯 걍 환불받고싶음',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2016, 7, 22, 1, 43),
#   0],
#  ['stay****',
#   '처음부터 끝까지 좀비들은 캭캭 거리기만하고 나머진 하루종일 문만 열었다가 닫았다가 반복 진짜진짜 노잼',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2016, 7, 20, 23, 19),
#   0],
#  ['미소녀 사냥꾼(love****)',
#   '엄청 재미 없다. 도대체 이런 내용 뻔한 영화에 제작비 수백억 낭비하는 자들의 돈에 대한 개념과 돈 가치에 대한 개념을 이해 할 수가 없다.',
#   '1',
#   '23',
#   '3',
#   datetime.datetime(2016, 7, 20, 14, 11),
#   0],
#  ['kimh****',
#   '소희 연기개못함 일점ㅡ',
#   '1',
#   '24',
#   '4',
#   datetime.datetime(2016, 7, 21, 17, 45),
#   0],
#  ['폭간섹비(girl****)',
#   '스토리는 둘째치고 억지눈물짜내기 진짜 심한데 심지어 하나도 안슬픔',
#   '1',
#   '24',
#   '4',
#   datetime.datetime(2016, 7, 21, 15, 4),
#   0],
#  ['바헬(12wj****)',
#   '돈많고 시간많은 사람은 보세요. 불면증환자에겐 좋은영화!!!',
#   '1',
#   '24',
#   '4',
#   datetime.datetime(2016, 7, 21, 10, 10),
#   0],
#  ['lsh9****',
#   '7번방급 억지 감동 억지 연출 물론 연기는 7번방 아래',
#   '1',
#   '24',
#   '4',
#   datetime.datetime(2016, 7, 21, 7, 42),
#   0],
#  ['지인(thsw****)',
#   '1점도아까워 최악. 제발 이런영화는 만들지 말길정말 보고나와서 집오는 내내 기분나쁨  킬링타임용으로도 이딴영화는 두번다시보고싶지않음 . 도대체 알바들을 얼마나 푼거임?',
#   '1',
#   '25',
#   '5',
# ...
#   '2',
#   datetime.datetime(2016, 7, 23, 9, 4),
#   0],
#  ['kisu****',
#   '마지막에 정유미 총 맞고 죽었으면 그자리에서 일어나 개욕했을뻔.마동석빼고 볼게 없음. 보는내내 고구마 10개 한꺼번에 먹은듯. 초반부터 이상해보였던 노숙자도 실마리를 풀어줄지 알았지만 그냥 희생양에 불과하고 전반적으...',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 23, 1, 6),
#   0],
#  ['Cat Shit One(djaa****)',
#   '헬좆센 좀비물이라는 점에서는 박수를 쳐주지만 애새끼 때문에 암 생길뻔 함. 들창코에 남자인줄알았다',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 22, 3, 29),
#   0],
#  ['pjk3****',
#   '재미없고 연기도 별로임 에구 내 시간 ㅜ',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 22, 1, 29),
#   0],
#  ['Partina(gkcl****)',
#   '보는내내 답답하고 중후반부터는 억지 눈물짜내기와 애우는 소리때문에 짜증만 나는 영화, 한국영화의 발전 가능성은 보았지만 거품이 너무 심하고 6~7점정도가 적당하다고 봄',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 22, 0, 23),
#   0],
#  ['Kt(were****)',
#   '핵노잼 후반부 억지 다쥭음',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 21, 12, 3),
#   0],
#  ['reds****',
#   '안보고 내용이 궁금해서 죽을거 같던가 보고 암걸려서 죽을거 같던가 둘 중 하나입니다. 그냥 마동석 보려고 보는 영화',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 21, 10, 21),
#   0],
#  ['Rood(91y1****)',
#   '보급형 한국식 좀비 지렸습니다.피토하며 관절비트는데 중간중간 하품하고 나왔습니다이게 왜 1위인지 정말 화가치밉니다',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 20, 17, 56),
#   0],
#  ['아스나(yom5****)',
#   '이거볼시간 좀만더투자해서 집에서 편하게 갑철성 보세요^^',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 20, 16, 42),
#   0],
#  ['네도리(didr****)',
#   '한국은 좀비영화만들지말자 답이없다',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 20, 16, 42),
#   0],
#  ['인내를이루라(gdr6****)',
#   '딸이랑 조조 봤는데도 돈이 아까버',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2016, 7, 20, 13, 6),
#   0],
#  ['주나(juna****)',
#   '오오이야오옹 다시보니 꿀잼',
#   '8',
#   '11',
#   '3',
#   datetime.datetime(2018, 7, 30, 11, 41),
#   '관람객'],
#  ['ghdt****',
#   '대한민국 좀비영화의 시작이라는 이유로 점수1점줌. . . 자극도안되는 감성자극하려고 너무 노래넣고. . 대화넣고. . 유치함',
#   '2',
#   '11',
#   '3',
#   datetime.datetime(2018, 1, 26, 23, 38),
#   0],
#  ['바닐라빈(cool****)',
#   '이게뭔한국형 좀비블록버스터?웬만한 막장드라마보다 더 발암..김의성역이랑 돌아이할매때문에 다 죽고..난 또 돌아이할매가 문열어서 김의성역 감염되는 줄 알았더니 끝까지 살아서 개민폐 애새꾸도 짜증..꼭 내용을 저렇게까지...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 12, 12, 1, 8),
#   0],
#  ['내가 최고야(rosa****)',
#   '할머니 부분이 제일 슬프고 사이다임',
#   '7',
#   '11',
#   '3',
#   datetime.datetime(2017, 10, 6, 21, 56),
#   0],
#  ['love****',
#   '악역착한역 나쁜일착한일 너무1차원적으로 나눔 유치함 런닝맨 좀비편을 영화로 만들었네',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 10, 6, 19, 30),
#   0],
#  ['루프리(quer****)',
#   '이 영화가 왜 좋은지 높이 평가받는지 이해할 수가 없다',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 10, 6, 15, 54),
#   0],
#  ['zito****',
#   '명량 해운대를 뛰어넘는 제일 불가사의한 천만영화 아닌가요...이거 보고 평점 후하게 주는 인간들은 정말 다른 외국영화 도 좀 보세요 제발제발...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 9, 20, 23, 1),
#   0],
#  ['limeyeon(hayo****)',
#   '한국영화특유의  감성팔이를 잘 보여줌^^',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 8, 3, 3, 59),
#   0],
#  ['ㅇ(chjs****)',
#   '내 인생 최악의 영화.  영화 재밌다는 애덜은 조금 불쌍하더라.  얼마나 문화생활을 안해 봤으면. . .보는 내내 어설퍼서 웃은 영화',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 30, 4, 45),
#   0],
#  ['na19****',
#   '공유와 마동석이 아까운 영화... 개연성이 없다.. 아무리 좀비물이라고 해도 왜 좀비가 나왔고 어떻게 전국에 전파가 됐는지 알수가 없어 몰입을 할 수 없었고, 진부한 캐릭터 설정이 억지 감동코드를 만들겠구나 미리 예...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 28, 2, 30),
#   0],
#  ['호호호(sang****)',
#   '좀비영화의 묘미가전혀업고억지감성팔이만나온다 개노잼',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 26, 20, 38),
#   0],
#  ['별명(jull****)',
#   '보는 내내 화가 치밀어 오르고 앞뒤 안맞는 전개에 짜증남 일관성없는 좀비의 공격성과 감염속도..내용이 어처구니 없어서 답답함에 내가 감염될뻔 억지감동에 눈물 한방울 안남 이걸 위해 팝콘콜라까지 산 과거의 나를 어떻게...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 26, 11, 3),
#   0],
#  ['타이탄(yuna****)',
#   '알바들 엄청 동원했군,..쓰ㄹㅔ ㄱ ㅣ 3류 좀비 영화  그이상 그이하도 아님....',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 25, 13, 27),
#   0],
#  ['반성한다(newp****)',
#   '따라쟁이 냄비족 한국인간들이까 천만넘게 봐주지 어디 외국에 한국에서 천만이 본 영화라고 팔러다니지 마라.. 단체환불은 니 사정이고 일단  개쪽팔린다..  2시간동안 인고의 시간이 지난 후  감독 면상을 쥐뜯고 싶었다...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 25, 11, 58),
#   0],
#  ['craz****',
#   '삼류 드라마..돈이 아까움',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 25, 11, 17),
#   0],
#  ['sade****',
#   '저 명배우들을 데리고 뭐하는 짓 감독 능력이 의심된다 안소희 그리고 소희남친으로 나온 남자애 진짜 발연기 갑',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 24, 23, 47),
#   0],
#  ['choo****',
#   '보다가 나온 영화 처음이다아역 연기는정말 최악이다버스 사장인가보다 다 짜증난다그리고 부산행 볼려면  나우행!!봐라',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 23, 14, 28),
#   0],
#  ['fore****',
#   '어휴.... 해도해도 너무한다ㅋㅋㅋ 내돈ㅜㅜㅜ내시간ㅜㅜㅜ',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 23, 10, 41),
#   0],
#  ['minsun3419(hkhl****)',
#   '재미도 없고 감동도 없는 영화',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 22, 16, 27),
#   0],
#  ['스타시커(star****)',
#   '난리나게놀라운영화입니다',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 22, 8, 56),
#   0],
#  ['sude****',
#   '정말 뻔한 내용에 재미라고는 하나도 없고 결말도 없고소희 그년은 왜 나와서 연기하는거야?? 진짜 검증안된 아이돌들 출연좀 시키지마라',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 22, 8, 54),
#   0],
#  ['정기원(jkw0****)',
#   '외국영화따라한 할말이 없는 영화',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 22, 6, 18),
#   0],
#  ['jhba****',
#   '엉청난 기대를 하고 본영화지만상당히내용불친절한 B급영화짜증유발 시키는 아역배우 몰입도 떨어지는 배우억지로 스토리를 끌고나가는 듯한 후반부까지 안봤으면 좋았을 기대만 하고 있었음 좋았을 영화',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 21, 12, 4),
#   0],
#  ['꽁치깡(yjbl****)',
#   '좀비분장은 부산행... 스토리는 안드로메다행...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 21, 8, 12),
#   0],
#  ['김프로(belo****)',
#   '억지감동발연기진부한스토리뻔한전개어쩜 하나도 안비껴가는지이게 재미있다니 헐좀비연기까지 구린건 요근래 첨봤음마요미,공유,악역하신분 세분빼곤 하... 진짜 캐스팅 미스',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 21, 1, 38),
#   0],
#  ['김만경(aksr****)',
#   '원인과 결말이 없음보는내내 스트레스 받음',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 23, 10),
#   0],
#  ['Sento Isuzu(berk****)',
#   '태어나서 만원이 아깝긴 처음이다.. 시간낭비다',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 22, 49),
#   0],
#  ['sinkbol123(jkln****)',
#   '와...무슨 바이러스 퍼진이유도 안나오고 무슨 내용이 이따구냐 스토리도 이해가안돼 바이러스 퍼진이유라도알아야지',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 19, 16),
#   0],
#  ['crm0****',
#   '진짜 오지라퍼 등장인물들의 발암이 마동석의 신들린 연기를 다깎아먹은듯;; 영화보고나서 더 찜찜하다연출은 나름 스케일도 크고 볼만한 것 같았는데 꼬마랑 상무아저씨 둘이서 다 쌈싸먹어버림.',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 16, 11),
#   0],
#  ['asdc****',
#   '진짜 장난하나...그냥 누구나 아는 내용의 좀비이야기누구나 예상가능한...이렇게 시나리오 다른 것들에서 다 짜깁기해서 영화만들어도 됩니까?',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 13, 54),
#   0],
#  ['대박연대(waah****)',
#   '평점알바 쫙 깔렸네요ㅠㅠ 절대 보지 마세요 ㅠㅠ 이건 쓰레기 중의 쓰레기고 돈 시간 낭비에다가  모처럼 극장나들이 기분만 잡치고 옵니다 ㅠㅠ',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2016, 7, 20, 12, 43),
#   0],
#  ['정문워(jmw6****)',
#   '합리적인 사고방식으로 의심을 하는 사람들을 몰살 시키는 발암 캐릭터에 공감하는 한국의 개돼지들',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2019, 2, 1, 23, 39),
#   0],
#  ['haramey(hara****)',
#   '월드워z를 보고 이 영화를 보니..',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2018, 2, 5, 19, 37),
#   0],
#  ['별에 취하고 싶다(byul****)',
#   '좀비 영화론 아직 멀었음..이게 왜 재밌다는건지.. -_-',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 12, 18, 0, 7),
#   0],
#  ['이택우(slrn****)',
#   '자 말합니다 마동석이 살아있을때까진 그나마? 볼만은 합니다....하지만 그 후엔..여기까지 말하도록 하겠습니다 진짜 외국 3류좀비영화가 더 재미지다고 보면됩니다 국뽕이라 천만 넘은거 같네요',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 11, 20, 0, 6),
#   0],
#  ['뭇잎공주(whwl****)',
#   '진짜 재미없다 아역개발암',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2017, 10, 29, 22, 47),
#   0],
#  ['츄츄앙(sito****)',
#   '이게천만?오글거려못봐주겠다.물려도 진즉 물릴듯한데 안물리고 안물릴수있을거같은데 물리기도하고.억지 감동 억지교훈..인간의 군중심리, 이기심표현하려는것도 유치짬뽕.아역은 답답해때려주고싶고 어이없는 장면들에 집중안된다.월...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 9, 18, 13, 41),
#   0],
#  ['fany****',
#   '아 ...정말 한마디로 아직어설픔 이였다. 좀비 연기하는것도 조금 웃겼고 임심부도 너무 잘뛰는것도 그렇고 마지막 부산행 열차  탈때 보니까 되게 천천히 가는데 좀비는 왜캐 못타고 있는건지  말이 안되는 부분이 있었음...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 8, 10, 17, 5),
#   0],
#  ['센스가이(yshh****)',
#   '진짜 영화관에서 화나보기는 첨이네 내용도 없고 개연성 제로에 신파로 떡칠하고 엔딩신에서 욕하는사람도 있더라... 끝나고 여기저기서 아이씨, 한숨쉬는 사람들 터져나오고 에휴 돈아까워미치겟네 ㅡㅡ 개짜증난다 진심',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 8, 3, 6, 1),
#   0],
#  ['엔앰러브(rubi****)',
#   '딱 칼링타임용 이네요 비추 합니다',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 28, 0, 8),
#   0],
#  ['최민경(mann****)',
#   '억지 눈물 유발에 설국열차마냥 ktx에 갇힌 답답한 영화. 상무라는 사람이 가장 현실적이구만 욕먹고 쓰레기 되는걸 보면 관객들은 15세도 안되는듯. 마동석 죽은뒤로 아예 보기싫어짐.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 26, 21, 34),
#   0],
#  ['마루(1rev****)',
#   '진짜 뜬금없다. 참 잘잤다. 좀비라는게 한국에 정서에 얼마나 맞을까 .. 이 알바들아,',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 25, 13, 25),
#   0],
#  ['내싸랑흑형(shin****)',
#   '내가 근래에 본 한국영화중 최악이었다   몇몇 배우들 연기가 별로였다는 사람들이 많은데 그보다 스토리 전개도 꽝이고 너무 말도 안되는 것들도 많다. 그리고 스토리도뚝뚝끊어먹고 왜 바이러스가 퍼졌는지, 어떻게 퍼졌는지...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 23, 11, 27),
#   0],
#  ['tjdg****',
#   '살면서 평점 처음남겨봐요 진짜 할머니분장부터해서 소희최우식연기에다가 개연성1도없고 최악',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 23, 11, 24),
#   0],
#  ['심판매수촌북(jcko****)',
#   '영화 28주후 본 사람은 나랑 같은 심정일꺼다.. 하아...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 22, 16, 37),
#   0],
#  ['sally(kbc6****)',
#   '기대보다 별로임 진짜 좀 잘만들수 있었는데',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 22, 8, 16),
#   0],
#  ['대환씨(eogh****)',
#   '반개도아까움억지감정으로음악깔고공유딸이 연기를못함 마지막노래씬은 정말듣기싫었음',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 21, 16, 35),
#   0],
#  ['곰나으리(gona****)',
#   '솔직히 아역 배우 진짜 와... 연기를 못하면 좀 귀엽기라도 하든가... 가뜩이나 뻔하고 오그라드는 스토리인데  애까지 그러니까 환장하겠더만. 스포일러 어쩌고 해서 스토리가 탄탄한가 했는데 그것도 아니고. 진짜 최악...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 21, 14, 9),
#   0],
#  ['유하(hyh0****)',
#   '....;;; 월드워Z를 중국짝퉁시장에서... 그것도 만들다가 중간에 포기해버린... 짝퉁영화같음...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 20, 22, 39),
#   0],
#  ['레모닛(cgew****)',
#   '남자앤지 여자앤지도 모르겠고 왠지 전쟁터에 나올것같은 애를 집어넣었네... 감독친척인가...다른 배우들은 괜찮은것 같은데...어쨋든 감정이입이안됨..이름도수완인가...  치마입은거보고여자앤줄암.예매율1위라길래봣더니 ...',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 20, 21, 25),
#   0],
#  ['빵(akdr****)',
#   '한국 사회의 이기적인 면과 뉴스는 믿을 수 없다 라는 것만 보여준 영화, 왜 바이러스 감염 원인과 핵신은 어디감? 핵신이 없더라도 결말이 왜 이럼..',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 20, 20, 10),
#   0],
#  ['동글이(ly14****)',
#   '저에겐 최악중최악. 암 유발 쉬운 분들은 이 영화 보지 마세요^^',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 20, 16, 57),
#   0],
#  ['절오빠(neww****)',
#   '하....이십.새끼 폭스사같은 영화',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2016, 7, 20, 12, 28),
#   0],
#  ['바넬로피(ske4****)',
#   'TV 전기세가 아까울정도인데 이런 영화가 천만이 넘다니 ㅎㅎ',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2019, 6, 20, 17, 53),
#   0],
#  ['2dj(edj6****)',
#   '여기 출연한 사람들이 전문배우인지조차 의심스럽다. 하나부터 열까지 모두 발연기에 상황연출도 어처니구없이 유치하다. 3~5점 정도가 적당하지만 평점조절을 위해 1점만준다',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 11, 12, 1, 6),
#   0],
#  ['jhyu****',
#   '이런 영화가 천만넘으면 월드워 정도는 2천만 넘어야겠네',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 10, 14, 20, 11),
#   0],
#  ['이상훈(8888****)',
#   '기자, 평론가 평점이 이렇게 높은건 처음 본다....역시 돈이 지배하는 세상이구나..',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 9, 30, 23, 19),
#   0],
#  ['zomb****',
#   '평론가도 김영란법 적용되어야 합니다...돈을 얼마나 받아먹었는지 한심하네요 그게 아니라면 진심 국뽕환자고',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 9, 26, 21, 16),
#   0],
#  ['꽃내음(ablu****)',
#   '정말 좋아하는 배우들 나왔는데한국 좀비 영화의 새로운 가능성 빼고는썩.... 억지감동이며 CG나 주연급 배우들은 처음부터 끝까지 한군데 뭉처 나옴 이게뭐야...차라리 다른걸 줄이고 리얼리티를 높였으면   진짜 썩.....',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 9, 17, 10, 52),
#   0],
#  ['BokSome(lapl****)',
#   '너무 비현실적 허접에서 꽁트인줄 ㅡㅡㅋ 아니 무슨 수많은 좀비들을 한번도 안물리고 다 쳐내더니 ㅋㅋ 마지막에 늙다리 할배좀비 하나 못 이겨서 분유광고찍음? 아 발로쓴 시나리오인듯 ㅡㅡ 공유나오는 드라마는 흥하는데 영...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 8, 15, 20, 6),
#   0],
#  ['asuk****',
#   '이건 좀 아닌듯.... 믿도끝도없다.',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 8, 7, 22, 19),
#   '관람객'],
#  ['호쯔(yumi****)',
#   '한국영화는 그냥 보지 마세요... 좀비영화로까지 신파극 찍으려고 합니다.',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 30, 22, 29),
#   0],
#  ['rhdu****',
#   '★경고★ 제말을 꼭 들으십쇼. 이 영화를 기대하고 보시면 100%후회하게됩니다.. 단순한 스토리라인만으로 2시간가까이되는 런타임을 이끌고 갈것인가에 대한 의문이 생겼었는데...반전이라도 있을줄 알았더니만 그냥 허무하...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 25, 23, 32),
#   0],
#  ['소심한비형(firs****)',
#   '방금봤는데 진짜 보지마라  물리고난후 감염진행  속도도 일정치않게 들쑥날쑥해서 말도 안되고 뜬금없는 대사에 아무튼 걍 보지마 쓰레기임',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 24, 5, 2),
#   0],
#  ['테디(hide****)',
#   '너무 미친 재미없어서 인생 첫 평점 남기려고 들어왔습니다.  심형래의 디워 젝키나왔던 세븐틴 이후로 최악의 영화네요. 기승전결파괴ㅋ스토리없음 제작비 많이들었다는데 cg는 최악 세트는 기차밖에 없고 그 제작비 지금 댓...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 24, 4, 18),
#   0],
#  ['센치(mado****)',
#   '아역 정말 짜증남. 발연기는 둘째치고 남자인지 여자인지 알수 없는 생김새에 비호감 대사만 날린다. 그리고 한국영화는 왜 억지눈물을 쥐어짜내려 하는가. 하나도 안슬프고 감동도 없거든!!',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 23, 16, 35),
#   0],
#  ['jjju(ant0****)',
#   '스토리 전개가....',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 22, 17, 34),
#   0],
#  ['덜탱이(cobb****)',
#   '억지 설정의 퍼레이드- 뛸때는 우사인볼트고 걸을땐 임산부-',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 22, 15, 45),
#   0],
#  ['bbanju(psju****)',
#   '좀비영화 많이 보셨던 분은 비추천',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 22, 9, 42),
#   0],
#  ['문주현(toru****)',
#   '개연성이 너무 없어서 나오면서 돈 아까웠음... 지금 보지 마시고 담에 티비에서 해줄 때 보세요 ㅋㅋ 진짜 돈 아까움...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 22, 3, 25),
#   0],
#  ['blub****',
#   '진짜 결론없는 최악의 영화 별 하나도 아깝다. 좀비에 쫓기다가 끝났네.  극후반부 너무 억지스럽다',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 21, 16, 1),
#   0],
#  ['다이킹(diyk****)',
#   '개인 취향이겠지만 정말 비추!!!내용 플랫하고.. 연기력이랄 것도 없고.. 딸내미 역할 배우만 앞으로 매력적으로 성장하겠다싶은 ㅡㅡ',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2016, 7, 21, 9, 31),
#   0],
#  ['뭐(gpdl****)',
#   '공유딸역이 답답함 쓸데없는 오지랖 저 상황에서는 공유처럼 자기부터 챙기는게 맞지',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2019, 8, 29, 12, 7),
#   0],
#  ['박실장2(sozz****)',
#   '발연기, 90년대식 앵글, 웹소설급 삼류 스토리, 어줍짢은 정부 은폐 설정, 암걸리는 애새끼 임산부. 1점도 아까운 클리셰 범벅 신파극이다.막눈깔 개돼지들이 수백만 찍어주니까 이딴 쓰레기 계속 찍어내지',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 11, 15, 0, 56),
#   0],
#  ['r2ff****',
#   '최악 삼류 좀비영화..',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2016, 10, 7, 13, 1),
#   0],
#  ['박선경(yxy1****)',
#   '별 반개도 주기 아깝다. 쒸레기영화',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2016, 9, 17, 10, 51),
#   0],
#  ['sunm(sunm****)',
#   '공유회상씬과 할머니문열기시전씬은 어이가 없어서 현웃이ㅋㅋㅋㅋ그리고마지막 꼬마의 노래씬은 정말...ㅎㅎ...인간인걸 알리려는 의도였겠지만 내눈엔 좀비모여라~~~죽을려고 환장한걸로 밖에 안보였음.  진짜 개연성과 기승전...',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2016, 7, 28, 1, 12),
#   0],
#  ['기하딱(ehdt****)',
#   '진짜 기대안하고 봐도 재미없다 재미가 없으면 내용이 시원하게 이어가든가 답답하고 암걸리네요  그리고 연기는 왜이리 어색해 좀비영화가 아니라 감성자극 영화인지 쓸데없는 감성팔이 ,',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2016, 7, 21, 17, 52),
#   0],
#  ['화성전선(nzin****)',
#   '그냥 말이필요없다 재미없다',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2016, 7, 20, 19, 31),
#   0],
#  ['HEE(rain****)',
#   '이게 왜 평이 높은지 이해가 안간다 알바아님? 시간아깝게 이거 보지말고 차라리 월드워z 한번 더 볼껄 봐도봐도 재밌는데',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2018, 1, 22, 17, 16),
#   0],
#  ['music doctor(wind****)',
#   '140자만 되서 짧게 씁니다.보기전 미드 워킹데드 보세요,보고나면 이영화는 쓰레기 입니다.서론 본론 결말 아무것도 없습니다.영화 진행.. 답답합니다.좀비도 말도 안되게 바로 변신. 근데 물린 공유는 천천히 변신.일관...',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 10, 1, 0, 26),
#   0],
#  ['호호(yaes****)',
#   '개인적으로는 스토리도 없고 그래서 재미도 없엇음',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 8, 15, 2, 10),
#   '관람객'],
#  ['나무(2365****)',
#   '관객 짜증나게 하려고 영화 만든듯',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 8, 14, 18, 46),
#   '관람객'],
#  ['ㄷㅇㅇㅇ(tmdg****)',
#   '보는내내발암이엇음 결망까지..',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 26, 0, 15),
#   '관람객'],
#  ['없음(muam****)',
#   '잠온다  진심  왠만하면 극장서 보지 마라',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 24, 22, 23),
#   '관람객'],
#  ['깨순이(yyy0****)',
#   '너무 짜낸 스토리 같아서 실망감이 컸어요',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 24, 1, 12),
#   '관람객'],
#  ['쥐방울(bys0****)',
#   '기대 하고 같는대 기대치가 너무 컸다 기대 이하 조잡함',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 24, 0, 56),
#   '관람객'],
#  ['나와같다면(hej7****)',
#   '영화 개잼없네 머 이런영화가 다있대, 위에 평점들 다 거짓말 한번보면 알아요 후회만빵',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 22, 7, 28),
#   0],
#  ['H(wkrr****)',
#   '내가 이 영화를 왜 봤을까... 신파 좀 그만해',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2016, 7, 22, 7, 12),
#   0],
#  ['osh3****',
#   '기대도 안하고 갔는데 짜증만 나서 돌아옴. 연기는 마동석 정유미만 좋았다. 안소희 나올 때마다 진심 몰입 깨져서 짜증나더라 설국열차,월드워Z 영화들이 떠오르는 장면들이 많았고 억지스러운 신파영화 마지막 엔딩까지 화나...',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2016, 7, 25, 23, 50),
#   '관람객'],
#  ['dn(jehu****)',
#   '내시간 X나 아깝다. 영화매니아로서 이건 정말 호객행위라고 밖에 안느껴짐 진심 참고하고 보세요 집단선동 당해서 영화보고 허탈가득한 얼굴로 영화관에서 나오는 분들 개많음 ㅋㅋㅋㅋ이성이란게 있다면 내말이 뭔줄 알겠지',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2016, 7, 22, 10, 35),
#   0],
#  ['비수(kdy4****)',
#   '배우 연기력 10망..물론 몇몇 진짜배우 제외.. 개연성 떨어지는 스토리.. 악역이 너무 오바하면서연기해서 몰입감 떨어짐.. 물론 몰입은 아역이 거의 망쳐놨지.. 내적 탄탄하지도않았고 노잼인데 언플 엄청 해대고 댓글...',
#   '3',
#   '17',
#   '9',
#   datetime.datetime(2016, 7, 20, 8, 27),
#   0],
#  ['임지현(wlak****)',
#   '한국을 배경으로 한 영화임에도 흥미진진했어요',
#   '10',
#   '20',
#   '12',
#   datetime.datetime(2016, 7, 20, 17, 15),
#   '관람객'],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                          0  ...    6
# 0            순수인(kjni****)  ...    0
# 1                 20fh****  ...  관람객
# 2          ㄹㅇㅁㄻㅇ(wjse****)  ...    0
# 3            kpl(lkp7****)  ...  관람객
# 4              쥘(sgre****)  ...    0
# ...                    ...  ...  ...
# 57995        사기꾼(yame****)  ...    0
# 57996  hiorangNa(anna****)  ...    0
# 57997             knev****  ...  관람객
# 57998             lemo****  ...  관람객
# 57999        방지현(step****)  ...    0
#
# [58000 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                   nickname  ... watch_movie
# 0            순수인(kjni****)  ...           0
# 1                 20fh****  ...         관람객
# 2          ㄹㅇㅁㄻㅇ(wjse****)  ...           0
# 3            kpl(lkp7****)  ...         관람객
# 4              쥘(sgre****)  ...           0
# ...                    ...  ...         ...
# 57995        사기꾼(yame****)  ...           0
# 57996  hiorangNa(anna****)  ...           0
# 57997             knev****  ...         관람객
# 57998             lemo****  ...         관람객
# 57999        방지현(step****)  ...           0
#
# [58000 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
